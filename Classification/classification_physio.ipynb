# %% [markdown]
# # Classification of Stress from Physiological data

# %%
# %matplotlib widget
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.figure as figure
import pandas as pd
from datetime import datetime
import joblib

from IPython.display import display

from imblearn.over_sampling import ADASYN, SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, VotingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import LinearSVC, SVR, SVC
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.pipeline import Pipeline

from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, SimpleImputer
from sklearn.preprocessing import StandardScaler, MaxAbsScaler, RobustScaler
from sklearn.feature_selection import RFECV

from make_classification import avg_res, make_nclassif_random_splits, make_nclassif_kfold

BASE_PATH = "../../stressid-dataset"
LABELS_SEPARATOR = ","
LABELS_FILENAME = "../stressID/labels.csv"
FEATURES_SEPARATOR = ","
FEATURES_DIRECTORY = "../Reprod-Features-NK"
# FEATURES_FILENAME = f"{FEATURES_DIRECTORY}/all_physiological_features.csv"
FEATURES_FILENAME = f"{FEATURES_DIRECTORY}/ecg_eda_features.csv"
RESULTS_SEPARATOR = ";"
RESULTS_DIRECTORY = "../stressID/Classification/Results"
BIN_LABELS = ["NoStress", "Stress"]
TER_LABELS = ["Relaxed", "Stress", "RealStress"]
QAD_LABELS = ["Relaxed", "Stress", "RealStress", "Amused"]
DEBUG = True

# %%
def make_results_filename(classification: str, splits: int, feature_selection: str | None, test_size: float, state_int: int) -> str:
    now = datetime.now()
    timestamp = now.strftime("%Y%m%d-%H%M%S")
    feature_selection = feature_selection if feature_selection is not None else "None"
    return f"{BASE_PATH}/{RESULTS_DIRECTORY}/{timestamp}_{classification}_{splits}s&{test_size}_{feature_selection}f.{state_int}"

def show_label_stats(labels: list[str], y: pd.Series):
    display(pd.DataFrame(
        {
            "labels": labels,
            "counts": y.value_counts().to_list(),
            "percentage": (y.value_counts(normalize=True) * 100).to_list(),
        }
    ))

def output(results: pd.DataFrame, conf_matrices: dict[str, np.ndarray], meta: dict):
    classification = meta['classification']
    n_splits = meta['n_splits']
    feature_selector = meta['feature_selector']
    test_size = meta['test_size']
    state_int = meta['state_int']
    labels = meta['classes']
    averages = avg_res(results)
    if meta['save_results']:
        res_file = make_results_filename(classification, n_splits, feature_selector, test_size, state_int) + ".csv"
        avg_file = make_results_filename(classification, n_splits, feature_selector, test_size, state_int) + ".avg.csv"
        print(f"Saving results to {res_file}, {avg_file}")
        results.to_csv(res_file, sep=RESULTS_SEPARATOR, index=True)
        averages.to_csv(avg_file, sep=RESULTS_SEPARATOR, index=True)

    # Show results
    if meta['show_averages']:
        display(averages)
    if meta['show_confusion_matrices']:
        cm_file = make_results_filename(classification, n_splits, feature_selector, test_size, state_int) + ".CM.png"
        ncms = len(conf_matrices)
        pairs = [(name, cm) for name, cm in conf_matrices.items()]
        nrows = (ncms // 2) + (ncms % 2)
        fig, axes = plt.subplots(nrows, 2, figsize=(8, nrows*4))
        for (name, cm), ax in zip(pairs, axes.ravel()):
            disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
            disp.plot(cmap=plt.cm.Blues, ax=ax, colorbar=False)
            ax.set_title(name)
        fig.suptitle("Confusion Matrices")
        plt.tight_layout()
        if meta["save_results"]:
            print(f"Saving confusion matrix to {cm_file}")
            plt.savefig(cm_file, dpi=300, format="png")
        plt.show()


def save_models(classifiers: dict[str, Pipeline], meta: dict):
    classification = meta["classification"]
    for name, cls in classifiers.items():
        now = datetime.now()
        timestamp = now.strftime("%Y%m%d-%H%M%S")
        filename = (
            f"{BASE_PATH}/{RESULTS_DIRECTORY}/{timestamp}_{classification}_{name}_{meta['feature_selector']}f.joblib"
        )
        joblib.dump(cls, filename)
        print(f"Model {name} saved to {filename}")

# %% [markdown]
# #### Import labels

# %%
labels = pd.read_csv(f"{BASE_PATH}/{LABELS_FILENAME}", sep=LABELS_SEPARATOR, header=0, index_col=0).dropna()
labels.head()
# Out:
#                 binary-stress  affect3-class  affect4-class
# subject/task
# 2ea4_Breathing              0              0              0
# 2ea4_Counting1              1              2              2
# 2ea4_Counting2              1              2              2
# 2ea4_Counting3              1              2              2
# 2ea4_Math                   1              2              2

# %% [markdown]
# # Classical approaches
#
# Several models are tested: Random Forests, K nearets neighbors, SVM, and Multi Layer Perceptron. All models are fitted 10 times on random splits, and the average scores over 10 repetitions are reported.
#
# The dimensionality of the features matrix can be reduced using PCA or Feature selection. Feature selection is performed using L1 penalty or Recursive Feature Elimination (RFE). The optimal number of features is determined using RFECV.

# %% [markdown]
# #### Import and prepare dataset
# We use handcrafted features.

# %%
X = pd.read_csv(f"{BASE_PATH}/{FEATURES_FILENAME}", sep=FEATURES_SEPARATOR, header=0, index_col=0)
display(X)
for col in X.columns:
    X[col] = X[col].astype(np.float32)
display(X)
# Out:
#                    meanHR      minHR       maxHR       sdHR      modeHR  \
# 2ea4_Baseline   63.430749  57.034221   79.575597   4.685361   22.541376
# 2ea4_Breathing  61.712623  45.871560   84.033613  11.009485   38.162054
# 2ea4_Counting1  70.973286  58.479532   82.872928   5.448858   24.393396
# 2ea4_Counting2  64.301095  56.285178   79.787234   5.497250   23.502056
# 2ea4_Counting3  66.253079  55.762082   80.645161   5.443328   24.883080
# ...                   ...        ...         ...        ...         ...
# y9z6_Reading    73.839596  54.545455  175.438596  19.184174  120.893142
# y9z6_Relax      58.768320  50.933786   75.000000   4.024016   24.066214
# y9z6_Speaking   79.574294  61.601643  176.470588  27.277891  114.868946
# y9z6_Stroop     64.712598  58.027079   73.710074   3.844910   15.682994
# y9z6_Video1     60.061811  53.191489   75.757576   3.685925   22.566086
#
#                       nNN       meanNN        SDSD        CVNN      SDNN  ...  \
# 2ea4_Baseline   62.000000   950.677419   41.894327   64.816310  0.068179  ...
# 2ea4_Breathing  59.666667  1002.893855  106.620821  173.316789  0.172817  ...
# 2ea4_Counting1  69.000000   850.550725   42.532503   67.603176  0.079482  ...
# 2ea4_Counting2  63.000000   939.587302   58.386027   76.102820  0.080996  ...
# 2ea4_Counting3  65.000000   911.661538   42.884190   74.003384  0.081174  ...
# ...                   ...          ...         ...         ...       ...  ...
# y9z6_Reading    70.000000   845.657143  141.770371  133.471012  0.157831  ...
# y9z6_Relax      58.000000  1025.475862   73.275208   66.397765  0.064748  ...
# y9z6_Speaking   73.000000   810.684932  171.499251  168.914413  0.208360  ...
# y9z6_Stroop     63.000000   930.412698   45.644284   54.586653  0.058669  ...
# y9z6_Video1     59.310345  1002.581395   59.116008   59.104060  0.058952  ...
#
#                  min_scl  mean_scl    sd_scl       nSCR      aucSCR  \
# 2ea4_Baseline  -1.132743  0.022668  0.891539  10.000000 -302.978934
# 2ea4_Breathing -0.968230 -0.006435  0.951185   7.333333  120.038332
# 2ea4_Counting1 -2.159093  0.012778  0.827482   7.000000  -92.589522
# 2ea4_Counting2 -1.167276 -0.011765  0.937448   6.000000  315.591734
# 2ea4_Counting3 -1.494708 -0.015553  0.904099  12.000000  558.708830
# ...                  ...       ...       ...        ...         ...
# y9z6_Reading   -1.017887 -0.000668  0.990734   2.400000  122.464218
# y9z6_Relax     -2.730086  0.022081  0.680286   5.000000  205.591732
# y9z6_Speaking  -1.291715 -0.029019  0.932817   5.000000  608.317194
# y9z6_Stroop    -1.833577  0.002666  0.974272   3.103448    5.575997
# y9z6_Video1    -1.142737  0.001318  0.998102   2.033898  -18.621149
#
#                 meanAmpSCR  maxAmpSCR  meanRespSCR  sumAmpSCR  sumRespSCR
# 2ea4_Baseline     0.666899   1.475682     1.160000   6.668994   11.600000
# 2ea4_Breathing    0.651699   1.748524     1.126095   4.779126    7.882667
# 2ea4_Counting1    0.860715   2.091642     2.433429   6.025006   17.034000
# 2ea4_Counting2    0.543249   1.502306     1.810000   3.259493   10.860000
# 2ea4_Counting3    0.721123   1.743292     1.282167   8.653481   15.386000
# ...                    ...        ...          ...        ...         ...
# y9z6_Reading      0.197116   0.600114    13.550667   0.473079   32.521600
# y9z6_Relax        0.939958   1.721442     2.791200   4.699788   13.956000
# y9z6_Speaking     0.320072   0.772637     1.639200   1.600359    8.196000
# y9z6_Stroop       0.310237   1.061803     3.314667   0.962805   10.286897
# y9z6_Video1       0.110889   0.243203     6.086667   0.225537    9.284746
#
# [773 rows x 70 columns]
#                    meanHR      minHR       maxHR       sdHR      modeHR  \
# 2ea4_Baseline   63.430748  57.034222   79.575600   4.685360   22.541376
# 2ea4_Breathing  61.712624  45.871559   84.033615  11.009485   38.162052
# 2ea4_Counting1  70.973282  58.479530   82.872925   5.448858   24.393396
# 2ea4_Counting2  64.301094  56.285179   79.787231   5.497250   23.502056
# 2ea4_Counting3  66.253082  55.762081   80.645164   5.443328   24.883080
# ...                   ...        ...         ...        ...         ...
# y9z6_Reading    73.839600  54.545456  175.438599  19.184174  120.893143
# y9z6_Relax      58.768322  50.933784   75.000000   4.024016   24.066214
# y9z6_Speaking   79.574295  61.601643  176.470581  27.277891  114.868942
# y9z6_Stroop     64.712601  58.027081   73.710075   3.844910   15.682995
# y9z6_Video1     60.061813  53.191490   75.757576   3.685925   22.566086
#
#                       nNN       meanNN        SDSD        CVNN      SDNN  ...  \
# 2ea4_Baseline   62.000000   950.677429   41.894325   64.816307  0.068179  ...
# 2ea4_Breathing  59.666668  1002.893860  106.620819  173.316788  0.172817  ...
# 2ea4_Counting1  69.000000   850.550720   42.532505   67.603180  0.079482  ...
# 2ea4_Counting2  63.000000   939.587280   58.386028   76.102821  0.080996  ...
# 2ea4_Counting3  65.000000   911.661560   42.884190   74.003387  0.081174  ...
# ...                   ...          ...         ...         ...       ...  ...
# y9z6_Reading    70.000000   845.657166  141.770370  133.471008  0.157831  ...
# y9z6_Relax      58.000000  1025.475830   73.275208   66.397766  0.064748  ...
# y9z6_Speaking   73.000000   810.684937  171.499252  168.914413  0.208360  ...
# y9z6_Stroop     63.000000   930.412720   45.644283   54.586655  0.058669  ...
# y9z6_Video1     59.310345  1002.581421   59.116009   59.104061  0.058952  ...
#
#                  min_scl  mean_scl    sd_scl       nSCR      aucSCR  \
# 2ea4_Baseline  -1.132743  0.022668  0.891540  10.000000 -302.978943
# 2ea4_Breathing -0.968230 -0.006435  0.951185   7.333333  120.038330
# 2ea4_Counting1 -2.159093  0.012778  0.827482   7.000000  -92.589523
# 2ea4_Counting2 -1.167276 -0.011765  0.937448   6.000000  315.591736
# 2ea4_Counting3 -1.494708 -0.015553  0.904099  12.000000  558.708801
# ...                  ...       ...       ...        ...         ...
# y9z6_Reading   -1.017887 -0.000668  0.990734   2.400000  122.464218
# y9z6_Relax     -2.730086  0.022081  0.680286   5.000000  205.591736
# y9z6_Speaking  -1.291716 -0.029019  0.932817   5.000000  608.317200
# y9z6_Stroop    -1.833577  0.002666  0.974272   3.103448    5.575997
# y9z6_Video1    -1.142737  0.001318  0.998102   2.033898  -18.621149
#
#                 meanAmpSCR  maxAmpSCR  meanRespSCR  sumAmpSCR  sumRespSCR
# 2ea4_Baseline     0.666899   1.475682     1.160000   6.668994   11.600000
# 2ea4_Breathing    0.651699   1.748524     1.126095   4.779126    7.882667
# 2ea4_Counting1    0.860715   2.091642     2.433429   6.025006   17.034000
# 2ea4_Counting2    0.543249   1.502306     1.810000   3.259493   10.860000
# 2ea4_Counting3    0.721123   1.743292     1.282167   8.653481   15.386000
# ...                    ...        ...          ...        ...         ...
# y9z6_Reading      0.197116   0.600114    13.550667   0.473079   32.521599
# y9z6_Relax        0.939958   1.721442     2.791200   4.699788   13.956000
# y9z6_Speaking     0.320072   0.772637     1.639200   1.600359    8.196000
# y9z6_Stroop       0.310237   1.061803     3.314667   0.962805   10.286897
# y9z6_Video1       0.110889   0.243203     6.086667   0.225537    9.284746
#
# [773 rows x 70 columns]

# %%
# Selecting rows that actually have entries in "labels" file
idx = list(X.merge(labels, left_index= True, right_index=True).index)
labels = labels.loc[idx]
x = X.loc[idx]

# %% [markdown]
# ### Parameter and models configuration

# %%
# Hyperparameters tunning

tunning_for = {
    "RandomForest": False,
    "KNN": False,
    "SVM": False,
    "MLP": False,
    "LogisticRegression": False,
}
randomized = False

if any(tunning_for.values()):
    from sklearn.model_selection import RandomizedSearchCV, GridSearchCV, train_test_split
    from scipy.stats import uniform

    search_class = RandomizedSearchCV if randomized else GridSearchCV

    state_int = 21
    y = labels["affect3-class"]

    ada = ADASYN(random_state=state_int, sampling_strategy={0: 400, 1: 400, 2: 400})
    x_in, y_in = ada.fit_resample(x, y)
    print("Resampled dataset")
    show_label_stats(TER_LABELS, y_in)

    def make_pipeline(model):
        return Pipeline(
            [
                ("imputer", IterativeImputer),
                ("scaler", StandardScaler),
                ("feature_selection", RFECV(RandomForestClassifier(max_depth=5), step=2, cv=2)),
                ("cls", model),
            ]
        )

    x_train, x_test, y_train, y_test = train_test_split(
        x_in, y_in, test_size=0.2, random_state=state_int
    )

    if tunning_for["RandomForest"]:
        print("Tunning RandomForestClassifier...")
        param_grid = {
            "cls__n_estimators": [100, 200, 300, 350, 400, 450, 500],
            "cls__max_depth": [None, 5, 10, 15, 20, 30, 40, 50],
            "cls__min_samples_split": [2, 5, 10],
            "cls__min_samples_leaf": [1, 2, 4],
            "cls__max_features": ["sqrt", "log2", None],
            "cls__bootstrap": [True, False],
        }
        search = search_class(
            make_pipeline(RandomForestClassifier()),
            param_grid,
        )
        search.fit(x_train, y_train)
        print(f"Best parameters found for RF: {search.best_params_}")
        print(f"Best score: {search.best_score_:.3f}")
        best_model = search.best_estimator_
        accuracy = best_model.score(x_test, y_test)
        print(f"Test set accuracy: {accuracy:.3f}")

    if tunning_for["KNN"]:
        print("Tunning KNeighborsClassifier...")
        param_grid = {
            "cls__n_neighbors": list(range(2, 21, 1)),
            "cls__weights": ["uniform", "distance"],
            "cls__p": [1, 2],
        }
        search = search_class(make_pipeline(KNeighborsClassifier()), param_grid)
        search.fit(x_train, y_train)
        print(f"Best parameters found for KNN: {search.best_params_}")
        print(f"Best score: {search.best_score_:.3f}")
        best_model = search.best_estimator_
        accuracy = best_model.score(x_test, y_test)
        print(f"Test set accuracy: {accuracy:.3f}")

    if tunning_for["SVM"]:
        print("Tunning SVM...")
        param_grid = {
            "cls__C": [0.1, 1, 10, 100, 1000, 5000, 10000],
            "cls__gamma": [
                "auto",
                "scale",
            ],
            "cls__kernel": [
                "rbf",
            ],
        }
        search = search_class(make_pipeline(SVC()), param_grid)
        search.fit(x_train, y_train)
        print(f"Best parameters found for SVM: {search.best_params_}")
        print(f"Best score: {search.best_score_:.3f}")
        best_model = search.best_estimator_
        accuracy = best_model.score(x_test, y_test)
        print(f"Test set accuracy: {accuracy:.3f}")

    if tunning_for["MLP"]:
        print("Tunning MLP...")
        param_grid = {
            "cls__hidden_layer_sizes": [
                (),
                (50,),
                (100,),
                (25, 25),
                (50, 50),
                (25, 25, 25),
                (50, 25, 25),
                (20, 50, 20),
            ],
            "cls__activation": ["tanh", "relu"],
            "cls__learning_rate_init": [0.0001, 0.0002, 0.0005, 0.0008, 0.001, 0.002, 0.005, 0.008, 0.01],
            "cls__alpha": [0.0001, 0.0002, 0.0005, 0.0008, 0.001, 0.002, 0.005, 0.008, 0.01],
        }
        search = search_class(
            make_pipeline(MLPClassifier(max_iter=10000)),
            param_grid,
        )
        search.fit(x_train, y_train)
        print(f"Best parameters found for MLP: {search.best_params_}")
        print(f"Best score: {search.best_score_:.3f}")
        best_model = search.best_estimator_
        accuracy = best_model.score(x_test, y_test)
        print(f"Test set accuracy: {accuracy:.3f}")

    if tunning_for["LogisticRegression"]:
        print("Tunning LogisticRegression...")

        print("\n\nlbfgs\n\n")
        param_grid = {
            "cls__C": np.logspace(-4, 4, 20),
            "cls__penalty": ["l2", None],
            "cls__solver": ["lbfgs", "newton-cg"],
            "cls__max_iter": [100, 1000, 2500, 5000],
        }
        search = search_class(make_pipeline(LogisticRegression()), param_grid)
        search.fit(x_train, y_train)
        print(f"Best parameters found for LogisticRegression: {search.best_params_}")
        print(f"Best score: {search.best_score_:.3f}")
        best_model = search.best_estimator_
        accuracy = best_model.score(x_test, y_test)
        print(f"Test set accuracy: {accuracy:.3f}")

        print("\n\nsaga\n\n")
        param_grid = {
            "cls__C": np.logspace(-4, 4, 20),
            "cls__penalty": ["l1", "l2", "elasticnet", None],
            "cls__solver": ["saga"],
            "cls__max_iter": [100, 500, 1000, 1500],
        }
        search = search_class(make_pipeline(LogisticRegression()), param_grid)
        search.fit(x_train, y_train)
        print(f"Best parameters found for LogisticRegression: {search.best_params_}")
        print(f"Best score: {search.best_score_:.3f}")
        best_model = search.best_estimator_
        accuracy = best_model.score(x_test, y_test)
        print(f"Test set accuracy: {accuracy:.3f}")


    raise Exception("Tunning finished. Please, set the best parameters found.")

# %%
params = {
    "state_int": 21,
    "feature_selector": 'RFE',  ###  None, 'PCA', 'L1', or 'RFE' (ordered by speed)
    "test_size": 0.2,  # Paper value: 0.2
    "n_splits": 10,  # Paper value: 10
    "save_results": True,
    "show_averages": True,
    "show_confusion_matrices": True,
    "data_augmentation": True,
    "save_models": True,
    "verbose": False,
}

validations = {
    'holdout': True,
    'kfold': True
}

list_classif = [
    RandomForestClassifier(max_depth=5, random_state=params["state_int"]),
    LogisticRegression(max_iter=5000),
    SVC(gamma="auto", kernel="rbf", random_state=params["state_int"]),
    MLPClassifier(max_iter=5000, hidden_layer_sizes=[], random_state=params["state_int"]),
]

# %% [markdown]
# ### Binary classification

# %%
params['classification'] = 'binary'
params['classes'] = BIN_LABELS
y = labels['binary-stress']
show_label_stats(params['classes'], y)

if params["data_augmentation"]:
    ada = ADASYN(random_state=params["state_int"], sampling_strategy={0: 650, 1:650})
    x_in, y_in = ada.fit_resample(x, y)
    print("Resampled dataset")
    show_label_stats(params["classes"], y_in)
else:
    x_in = x.copy()
    y_in = y.copy()
# Out:
#      labels  counts  percentage
# 0  NoStress     368   52.646638
# 1    Stress     331   47.353362
# Resampled dataset
#      labels  counts  percentage
# 0  NoStress     661   50.535168
# 1    Stress     647   49.464832

# %%
# 10 random splits holdout
if validations['holdout']:
    res, conf, models = make_nclassif_random_splits(
        x_in,
        y_in,
        n_splits=params["n_splits"],
        feature_selector=params["feature_selector"],
        list_classifiers=list_classif,
        random_seed=params["state_int"],
        test_size=params["test_size"],
        verbose=params["verbose"],
        useStratification=False,
    )
    output(res, conf, params)
    if params["save_models"]:
        save_models(models, params)

    print(f"Standard Deviations {params['n_splits']} holdouts:")
    display(res.groupby(["classifier"]).std()[["f1-score", "accuracy", "time"]])
# Out:
# Split  1/10
# Split  2/10
# Split  3/10
# Split  4/10
# Split  5/10
# Split  6/10
# Split  7/10
# Split  8/10
# Split  9/10
# Split 10/10
# Saving results to ../../stressid-dataset/../stressID/Classification/Results/20251012-143524_binary_10s&0.2_RFEf.21.csv, ../../stressid-dataset/../stressID/Classification/Results/20251012-143524_binary_10s&0.2_RFEf.21.avg.csv
#                         f1-score  accuracy       time
# classifier
# LogisticRegression      0.745436  0.746642  10.030912
# MLPClassifier           0.719285  0.720812  10.264535
# RandomForestClassifier  0.748600  0.750144  10.563827
# SVC                     0.763807  0.765238  10.232445
# Saving confusion matrix to ../../stressid-dataset/../stressID/Classification/Results/20251012-143524_binary_10s&0.2_RFEf.21.CM.png
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Model RandomForestClassifier saved to ../../stressid-dataset/../stressID/Classification/Results/20251012-143525_binary_RandomForestClassifier_RFEf.joblib
# Model LogisticRegression saved to ../../stressid-dataset/../stressID/Classification/Results/20251012-143525_binary_LogisticRegression_RFEf.joblib
# Model SVC saved to ../../stressid-dataset/../stressID/Classification/Results/20251012-143525_binary_SVC_RFEf.joblib
# Model MLPClassifier saved to ../../stressid-dataset/../stressID/Classification/Results/20251012-143525_binary_MLPClassifier_RFEf.joblib
# Standard Deviations 10 holdouts:
#                         f1-score  accuracy      time
# classifier
# LogisticRegression      0.028068  0.026941  0.992468
# MLPClassifier           0.024110  0.023226  1.509637
# RandomForestClassifier  0.033405  0.032828  1.301090
# SVC                     0.035527  0.034840  1.223708

# %%
# 5-fold cross-validation
if validations['kfold']:
    res, conf, models = make_nclassif_kfold(
        x_in,
        y_in,
        feature_selector=params["feature_selector"],
        list_classifiers=list_classif,
        random_seed=params["state_int"],
        verbose=params["verbose"],
        stratified=False,
    )
    output(res, conf, params)
    if params["save_models"]:
        save_models(models, params)

    print("Standard Deviations 5-folds cross-validation:")
    display(res.groupby(["classifier"]).std()[["f1-score", "accuracy", "time"]])
# Out:
# Fold 1/5
# Fold 2/5
# Fold 3/5
# Fold 4/5
# Fold 5/5
# Saving results to ../../stressid-dataset/../stressID/Classification/Results/20251012-143947_binary_10s&0.2_RFEf.21.csv, ../../stressid-dataset/../stressID/Classification/Results/20251012-143947_binary_10s&0.2_RFEf.21.avg.csv
#                         f1-score  accuracy       time
# classifier
# LogisticRegression      0.722614  0.724737  11.482462
# MLPClassifier           0.727070  0.729128  10.651082
# RandomForestClassifier  0.764615  0.765612  10.430557
# SVC                     0.775289  0.775893  11.325984
# Saving confusion matrix to ../../stressid-dataset/../stressID/Classification/Results/20251012-143948_binary_10s&0.2_RFEf.21.CM.png
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Model RandomForestClassifier saved to ../../stressid-dataset/../stressID/Classification/Results/20251012-143948_binary_RandomForestClassifier_RFEf.joblib
# Model LogisticRegression saved to ../../stressid-dataset/../stressID/Classification/Results/20251012-143948_binary_LogisticRegression_RFEf.joblib
# Model SVC saved to ../../stressid-dataset/../stressID/Classification/Results/20251012-143948_binary_SVC_RFEf.joblib
# Model MLPClassifier saved to ../../stressid-dataset/../stressID/Classification/Results/20251012-143948_binary_MLPClassifier_RFEf.joblib
# Standard Deviations 5-folds cross-validation:
#                         f1-score  accuracy      time
# classifier
# LogisticRegression      0.027176  0.024910  1.056613
# MLPClassifier           0.014730  0.015322  1.974912
# RandomForestClassifier  0.021792  0.019380  1.536282
# SVC                     0.010132  0.010787  1.480800

# %% [markdown]
# ### Ternary classification

# %%
params['classification'] = 'ternary'
params['classes'] = TER_LABELS
y = labels['affect3-class']
show_label_stats(params['classes'], y)

if params["data_augmentation"]:
    ada = ADASYN(random_state=params["state_int"], sampling_strategy={0: 400, 1:400, 2:400})
    x_in, y_in = ada.fit_resample(x, y)
    print("Resampled dataset")
    show_label_stats(params['classes'], y_in)
else:
    x_in = x.copy()
    y_in = y.copy()
# Out:
#        labels  counts  percentage
# 0     Relaxed     286   40.915594
# 1      Stress     271   38.769671
# 2  RealStress     142   20.314735
# Resampled dataset
#        labels  counts  percentage
# 0     Relaxed     439   37.015177
# 1      Stress     382   32.209106
# 2  RealStress     365   30.775717

# %%
# 10 random splits holdout
if validations["holdout"]:
    res, conf, models = make_nclassif_random_splits(
        x_in,
        y_in,
        n_splits=params["n_splits"],
        feature_selector=params["feature_selector"],
        list_classifiers=list_classif,
        random_seed=params["state_int"],
        test_size=params["test_size"],
        verbose=params["verbose"],
        useStratification=True,
    )
    output(res, conf, params)
    if params["save_models"]:
        save_models(models, params)

    print(f"Standard Deviations {params['n_splits']} holdouts:")
    display(res.groupby(["classifier"]).std()[["f1-score", "accuracy", "time"]])
# Out:
# Split  1/10
# Split  2/10
# Split  3/10
# Split  4/10
# Split  5/10
# Split  6/10
# Split  7/10
# Split  8/10
# Split  9/10
# Split 10/10
# Saving results to ../../stressid-dataset/../stressID/Classification/Results/20251012-150448_ternary_10s&0.2_RFEf.21.csv, ../../stressid-dataset/../stressID/Classification/Results/20251012-150448_ternary_10s&0.2_RFEf.21.avg.csv
#                         f1-score  accuracy       time
# classifier
# LogisticRegression      0.531182  0.533955  10.000522
# MLPClassifier           0.532569  0.534121   9.996849
# RandomForestClassifier  0.605242  0.609465  10.687950
# SVC                     0.648383  0.645607   9.183506
# Saving confusion matrix to ../../stressid-dataset/../stressID/Classification/Results/20251012-150448_ternary_10s&0.2_RFEf.21.CM.png
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Model RandomForestClassifier saved to ../../stressid-dataset/../stressID/Classification/Results/20251012-150449_ternary_RandomForestClassifier_RFEf.joblib
# Model LogisticRegression saved to ../../stressid-dataset/../stressID/Classification/Results/20251012-150449_ternary_LogisticRegression_RFEf.joblib
# Model SVC saved to ../../stressid-dataset/../stressID/Classification/Results/20251012-150449_ternary_SVC_RFEf.joblib
# Model MLPClassifier saved to ../../stressid-dataset/../stressID/Classification/Results/20251012-150449_ternary_MLPClassifier_RFEf.joblib
# Standard Deviations 10 holdouts:
#                         f1-score  accuracy      time
# classifier
# LogisticRegression      0.019794  0.018786  1.188488
# MLPClassifier           0.027273  0.027122  0.751477
# RandomForestClassifier  0.030533  0.031742  0.746687
# SVC                     0.016670  0.016091  0.794515

# %%
# 5-fold cross-validation
if validations["kfold"]:
    res, conf, models = make_nclassif_kfold(
        x_in,
        y_in,
        feature_selector=params["feature_selector"],
        list_classifiers=list_classif,
        random_seed=params["state_int"],
        verbose=params["verbose"],
        stratified=False,
    )
    output(res, conf, params)
    if params["save_models"]:
        save_models(models, params)

    print("Standard Deviations 5-folds cross-validation:")
    display(res.groupby(["classifier"]).std()[["f1-score", "accuracy", "time"]])
# Out:
# Fold 1/5
# Fold 2/5
# Fold 3/5
# Fold 4/5
# Fold 5/5
# Saving results to ../../stressid-dataset/../stressID/Classification/Results/20251012-151742_ternary_10s&0.2_RFEf.21.csv, ../../stressid-dataset/../stressID/Classification/Results/20251012-151742_ternary_10s&0.2_RFEf.21.avg.csv
#                         f1-score  accuracy       time
# classifier
# LogisticRegression      0.561022  0.566037   8.981514
# MLPClassifier           0.533250  0.535576  10.070717
# RandomForestClassifier  0.633529  0.636633  10.651161
# SVC                     0.661950  0.662556  12.283778
# Saving confusion matrix to ../../stressid-dataset/../stressID/Classification/Results/20251012-151742_ternary_10s&0.2_RFEf.21.CM.png
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Model RandomForestClassifier saved to ../../stressid-dataset/../stressID/Classification/Results/20251012-151743_ternary_RandomForestClassifier_RFEf.joblib
# Model LogisticRegression saved to ../../stressid-dataset/../stressID/Classification/Results/20251012-151743_ternary_LogisticRegression_RFEf.joblib
# Model SVC saved to ../../stressid-dataset/../stressID/Classification/Results/20251012-151743_ternary_SVC_RFEf.joblib
# Model MLPClassifier saved to ../../stressid-dataset/../stressID/Classification/Results/20251012-151743_ternary_MLPClassifier_RFEf.joblib
# Standard Deviations 5-folds cross-validation:
#                         f1-score  accuracy      time
# classifier
# LogisticRegression      0.022219  0.014423  0.876402
# MLPClassifier           0.025100  0.023719  1.624667
# RandomForestClassifier  0.039314  0.037482  1.010302
# SVC                     0.025485  0.023016  4.364742

# %% [markdown]
# ### Quaternary Classification

# %%
params["classification"] = "quaternary"
params["classes"] = QAD_LABELS
y = labels["affect4-class"]
show_label_stats(params["classes"], y)

if params["data_augmentation"]:
    ada = ADASYN(random_state=params["state_int"], sampling_strategy={0: 350, 1: 350, 2: 350, 3:350})
    x_in, y_in = ada.fit_resample(x, y)
    print("Resampled dataset")
    show_label_stats(params["classes"], y_in)
else:
    x_in = x.copy()
    y_in = y.copy()
# Out:
#        labels  counts  percentage
# 0     Relaxed     216   30.901288
# 1      Stress     194   27.753934
# 2  RealStress     167   23.891273
# 3      Amused     122   17.453505
# Resampled dataset
#        labels  counts  percentage
# 0     Relaxed     380   27.104137
# 1      Stress     361   25.748930
# 2  RealStress     334   23.823110
# 3      Amused     327   23.323823

# %%
# 10 random splits holdout
if validations["holdout"]:
    res, conf, models = make_nclassif_random_splits(
        x_in,
        y_in,
        n_splits=params["n_splits"],
        feature_selector=params["feature_selector"],
        list_classifiers=list_classif,
        random_seed=params["state_int"],
        test_size=params["test_size"],
        verbose=params["verbose"],
        useStratification=True,
    )
    output(res, conf, params)
    if params["save_models"]:
        save_models(models, params)

    print(f"Standard Deviations {params['n_splits']} holdouts:")
    display(res.groupby(["classifier"]).std()[["f1-score", "accuracy", "time"]])
# Out:
# Split  1/10
# Split  2/10
# Split  3/10
# Split  4/10
# Split  5/10
# Split  6/10
# Split  7/10
# Split  8/10
# Split  9/10
# Split 10/10
# Saving results to ../../stressid-dataset/../stressID/Classification/Results/20251012-154853_quaternary_10s&0.2_RFEf.21.csv, ../../stressid-dataset/../stressID/Classification/Results/20251012-154853_quaternary_10s&0.2_RFEf.21.avg.csv
#                         f1-score  accuracy       time
# classifier
# LogisticRegression      0.526151  0.529401  10.260177
# MLPClassifier           0.518634  0.520966  11.319052
# RandomForestClassifier  0.559239  0.569821  11.117806
# SVC                     0.632082  0.634452   9.926922
# Saving confusion matrix to ../../stressid-dataset/../stressID/Classification/Results/20251012-154853_quaternary_10s&0.2_RFEf.21.CM.png
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Model RandomForestClassifier saved to ../../stressid-dataset/../stressID/Classification/Results/20251012-154853_quaternary_RandomForestClassifier_RFEf.joblib
# Model LogisticRegression saved to ../../stressid-dataset/../stressID/Classification/Results/20251012-154853_quaternary_LogisticRegression_RFEf.joblib
# Model SVC saved to ../../stressid-dataset/../stressID/Classification/Results/20251012-154853_quaternary_SVC_RFEf.joblib
# Model MLPClassifier saved to ../../stressid-dataset/../stressID/Classification/Results/20251012-154853_quaternary_MLPClassifier_RFEf.joblib
# Standard Deviations 10 holdouts:
#                         f1-score  accuracy      time
# classifier
# LogisticRegression      0.024116  0.024020  0.619387
# MLPClassifier           0.030320  0.031051  1.450751
# RandomForestClassifier  0.031877  0.030268  1.019514
# SVC                     0.023982  0.023061  0.752582

# %%
# 5-fold cross-validation
if validations["kfold"]:
    res, conf, models = make_nclassif_kfold(
        x_in,
        y_in,
        feature_selector=params["feature_selector"],
        list_classifiers=list_classif,
        random_seed=params["state_int"],
        verbose=params["verbose"],
        stratified=False,
    )
    output(res, conf, params)
    if params["save_models"]:
        save_models(models, params)

    print("Standard Deviations 5-folds cross-validation:")
    display(res.groupby(["classifier"]).std()[["f1-score", "accuracy", "time"]])
# Out:
# Fold 1/5
# Fold 2/5
# Fold 3/5
# Fold 4/5
# Fold 5/5
# Saving results to ../../stressid-dataset/../stressID/Classification/Results/20251012-160509_quaternary_10s&0.2_RFEf.21.csv, ../../stressid-dataset/../stressID/Classification/Results/20251012-160509_quaternary_10s&0.2_RFEf.21.avg.csv
#                         f1-score  accuracy       time
# classifier
# LogisticRegression      0.509147  0.512895  10.770891
# MLPClassifier           0.481051  0.483921  10.684582
# RandomForestClassifier  0.563235  0.572017   9.736870
# SVC                     0.608402  0.611165  11.001226
# Saving confusion matrix to ../../stressid-dataset/../stressID/Classification/Results/20251012-160509_quaternary_10s&0.2_RFEf.21.CM.png
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Model RandomForestClassifier saved to ../../stressid-dataset/../stressID/Classification/Results/20251012-160509_quaternary_RandomForestClassifier_RFEf.joblib
# Model LogisticRegression saved to ../../stressid-dataset/../stressID/Classification/Results/20251012-160509_quaternary_LogisticRegression_RFEf.joblib
# Model SVC saved to ../../stressid-dataset/../stressID/Classification/Results/20251012-160510_quaternary_SVC_RFEf.joblib
# Model MLPClassifier saved to ../../stressid-dataset/../stressID/Classification/Results/20251012-160510_quaternary_MLPClassifier_RFEf.joblib
# Standard Deviations 5-folds cross-validation:
#                         f1-score  accuracy      time
# classifier
# LogisticRegression      0.045881  0.044273  0.666924
# MLPClassifier           0.045493  0.047209  1.462235
# RandomForestClassifier  0.026278  0.029252  0.483965
# SVC                     0.025877  0.027397  1.080741
