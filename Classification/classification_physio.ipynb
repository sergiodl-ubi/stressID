# %% [markdown]
# # Classification of Stress from Physiological data

# %%
# %matplotlib widget
import numpy as np
import scipy.io
import scipy.stats as stats
import matplotlib.pyplot as plt
import pandas as pd
import random
import time
from datetime import datetime

import os
from pathlib import Path
from IPython.display import display

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split, LeaveOneOut, GroupKFold
from sklearn.svm import LinearSVC, SVR, SVC
from sklearn.feature_selection import SelectFromModel
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import RFE
from sklearn.feature_selection import RFECV
from sklearn.metrics import balanced_accuracy_score, f1_score, ConfusionMatrixDisplay

from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.preprocessing import StandardScaler

from sklearn.utils import shuffle

from make_classification import avg_res, make_nclassif_random_splits

BASE_PATH = "../../stressid-dataset"
LABELS_SEPARATOR = ","
LABELS_FILENAME = "../stressID/labels.csv"
FEATURES_SEPARATOR = ","
FEATURES_DIRECTORY = "../Reprod-Features-NK"
FEATURES_FILENAME = f"{FEATURES_DIRECTORY}/all_physiological_features.csv"
RESULTS_SEPARATOR = ";"
RESULTS_DIRECTORY = "../stressID/Classification/Results"
BIN_LABELS = ["NoStress", "Stress"]
TER_LABELS = ["Relaxed", "Stress", "RealStress"]
QAD_LABELS = ["Relaxed", "Stress", "RealStress", "Amused"]
ONNX_OPSET = 21
DEBUG = True

# %%
def make_results_filename(classification: str, splits: int, feature_selection: str | None, test_size: float, state_int: int) -> str:
    now = datetime.now()
    timestamp = now.strftime("%Y%m%d-%H%M%S")
    feature_selection = feature_selection if feature_selection is not None else "None"
    return f"{BASE_PATH}/{RESULTS_DIRECTORY}/{timestamp}_{classification}_{splits}s&{test_size}_{feature_selection}f.{state_int}"

def show_label_stats(labels: list[str], y: pd.Series):
    display(pd.DataFrame(
        {
            "labels": labels,
            "counts": y.value_counts().to_list(),
            "percentage": (y.value_counts(normalize=True) * 100).to_list(),
        }
    ))

def output(results: pd.DataFrame, conf_matrices: np.ndarray, classifiers: list, meta: dict):
    classification = meta['classification']
    n_splits = meta['n_splits']
    feature_selector = meta['feature_selector']
    test_size = meta['test_size']
    state_int = meta['state_int']
    labels = meta['classes']
    averages = avg_res(results)
    if meta['save_results']:
        res_file = make_results_filename(classification, n_splits, feature_selector, test_size, state_int) + ".csv"
        avg_file = make_results_filename(classification, n_splits, feature_selector, test_size, state_int) + ".avg.csv"
        print(f"Saving results to {res_file} and {avg_file}")
        results.to_csv(res_file, sep=RESULTS_SEPARATOR, index=True)
        averages.to_csv(avg_file, sep=RESULTS_SEPARATOR, index=True)

    # Show results
    if meta['show_averages']:
        display(averages)
    if meta['show_confusion_matrices']:
        for confusion_matrix, clf in zip(conf_matrices, classifiers):
            disp = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix, display_labels=labels)
            disp.plot(cmap=plt.cm.Blues)
            disp.ax_.set_title(clf.__class__.__name__)
            plt.show()


def save_models(classifiers: dict[str, Pipeline], x: pd.DataFrame, meta: dict):
    for name, cls in classifiers.items():
        now = datetime.now()
        timestamp = now.strftime("%Y%m%d-%H%M%S")
        filename = f"{BASE_PATH}/{RESULTS_DIRECTORY}/{timestamp}_{name}_{meta['feature_selector']}f.pmml"
        # sklearn2pmml(cls, filename, with_repr=True)
        print(f"Model {name} saved to {filename}")

# %% [markdown]
# #### Import labels

# %%
labels = pd.read_csv(f"{BASE_PATH}/{LABELS_FILENAME}", sep=LABELS_SEPARATOR, header=0, index_col=0).dropna()
labels.head()
# Out:
#                 binary-stress  affect3-class  affect4-class
# subject/task
# 2ea4_Breathing              0              0              0
# 2ea4_Counting1              1              2              2
# 2ea4_Counting2              1              2              2
# 2ea4_Counting3              1              2              2
# 2ea4_Math                   1              2              2

# %% [markdown]
# # Classical approaches
#
# Several models are tested: Random Forests, K nearets neighbors, SVM, and Multi Layer Perceptron. All models are fitted 10 times on random splits, and the average scores over 10 repetitions are reported.
#
# The dimensionality of the features matrix can be reduced using PCA or Feature selection. Feature selection is performed using L1 penalty or Recursive Feature Elimination (RFE). The optimal number of features is determined using RFECV.

# %% [markdown]
# #### Import and prepare dataset
# We use handcrafted features.

# %%
X = pd.read_csv(f"{BASE_PATH}/{FEATURES_FILENAME}", sep=FEATURES_SEPARATOR, header=0, index_col=0)
display(X)
for col in X.columns:
    X[col] = X[col].astype(np.float32)
display(X)
# Out:
#                    meanHR      minHR  ...  sumAmpSCR  sumRespSCR
# 2ea4_Baseline   63.430749  57.034221  ...   6.668994   11.600000
# 2ea4_Breathing  61.712623  45.871560  ...   4.779126    7.882667
# 2ea4_Counting1  70.973286  58.479532  ...   6.025006   17.034000
# 2ea4_Counting2  64.301095  56.285178  ...   3.259493   10.860000
# 2ea4_Counting3  66.253079  55.762082  ...   8.653481   15.386000
# ...                   ...        ...  ...        ...         ...
# y9z6_Relax      58.768320  50.933786  ...   0.473079   32.521600
# y9z6_Speaking   79.574294  61.601643  ...   4.699788   13.956000
# y9z6_Stroop     64.712598  58.027079  ...   1.600359    8.196000
# y9z6_Video1     60.061811  53.191489  ...   0.962805   10.286897
# y9z6_Video2     59.562842  52.631579  ...   0.225537    9.284746
#
# [773 rows x 132 columns]
#                    meanHR      minHR  ...  sumAmpSCR  sumRespSCR
# 2ea4_Baseline   63.430748  57.034222  ...   6.668994   11.600000
# 2ea4_Breathing  61.712624  45.871559  ...   4.779126    7.882667
# 2ea4_Counting1  70.973282  58.479530  ...   6.025006   17.034000
# 2ea4_Counting2  64.301094  56.285179  ...   3.259493   10.860000
# 2ea4_Counting3  66.253082  55.762081  ...   8.653481   15.386000
# ...                   ...        ...  ...        ...         ...
# y9z6_Relax      58.768322  50.933784  ...   0.473079   32.521599
# y9z6_Speaking   79.574295  61.601643  ...   4.699788   13.956000
# y9z6_Stroop     64.712601  58.027081  ...   1.600359    8.196000
# y9z6_Video1     60.061813  53.191490  ...   0.962805   10.286897
# y9z6_Video2     59.562843  52.631580  ...   0.225537    9.284746
#
# [773 rows x 132 columns]

# %%
# Selecting rows that actually have entries in "labels" file
idx = list(X.merge(labels, left_index= True, right_index=True).index)
labels = labels.loc[idx]
x = X.loc[idx]

# %% [markdown]
# ### Parameter and models configuration

# %%
params = {
    "state_int": 21,
    "feature_selector": 'RFE',  ###  None, 'L1', 'PCA', or 'RFE' (ordered by speed)
    "test_size": 0.2,  # Paper value: 0.2
    "n_splits": 10,  # Paper value: 10
    "save_results": True,
    "show_averages": True,
    "show_confusion_matrices": True,
    "save_models": False,
}

list_classif = [RandomForestClassifier(max_depth=5, random_state=params['state_int']),
                KNeighborsClassifier(n_neighbors=3),
                SVC(gamma='auto', kernel='rbf', random_state=params['state_int']),
                MLPClassifier(max_iter=5000, random_state=params['state_int'], hidden_layer_sizes=[])
]

# %% [markdown]
# ### Binary classification

# %%
params['classification'] = 'binary'
params['classes'] = BIN_LABELS
y = labels['binary-stress']
show_label_stats(params['classes'], y)

res, conf, models = make_nclassif_random_splits(x, y,
                    n_splits = params['n_splits'],
                    feature_selector = params['feature_selector'],
                    list_classifiers = list_classif,
                    random_seed = params['state_int'],
                    test_size = params['test_size'],
                    )
output(res, conf, list_classif, params)
if params['save_models']:
    save_models(models, x, params)
# Out:
#      labels  counts  percentage
# 0  NoStress     367   52.503577
# 1    Stress     332   47.496423
# Split  1/10
# Split  2/10
# Split  3/10
# Split  4/10
# Split  5/10
# Split  6/10
# Split  7/10
# Split  8/10
# Split  9/10
# Split 10/10
# Saving results to ../../stressid-dataset/../stressID/Classification/Results/20260103-150801_binary_10s&0.2_RFEf.21.csv and ../../stressid-dataset/../stressID/Classification/Results/20260103-150801_binary_10s&0.2_RFEf.21.avg.csv
#                         f1-score  accuracy       time
# classifier
# KNeighborsClassifier    0.651022  0.647476  14.955800
# MLPClassifier           0.717756  0.712716  15.420777
# RandomForestClassifier  0.743978  0.737996  15.136605
# SVC                     0.737503  0.731641  13.930493
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print('Standard Deviations over 10 splits:')
res.groupby(['classifier']).std()[['f1-score', 'accuracy', 'time']]

# %% [markdown]
# ### Ternary classification

# %%
params['classification'] = 'ternary'
params['classes'] = TER_LABELS
y = labels['affect3-class']
show_label_stats(params['classes'], y)

res, conf, models = make_nclassif_random_splits(x, y,
                    n_splits = params['n_splits'],
                    feature_selector = params['feature_selector'],
                    list_classifiers = list_classif,
                    random_seed = params['state_int'],
                    test_size = params['test_size'],
                    )
output(res, conf, list_classif, params)
if params["save_models"]:
    save_models(models, x, params)
# Out:
#        labels  counts  percentage
# 0     Relaxed     285   40.772532
# 1      Stress     271   38.769671
# 2  RealStress     143   20.457797
# Split  1/10
# Split  2/10
# Split  3/10
# Split  4/10
# Split  5/10
# Split  6/10
# Split  7/10
# Split  8/10
# Split  9/10
# Split 10/10
# Saving results to ../../stressid-dataset/../stressID/Classification/Results/20260103-151839_ternary_10s&0.2_RFEf.21.csv and ../../stressid-dataset/../stressID/Classification/Results/20260103-151839_ternary_10s&0.2_RFEf.21.avg.csv
#                         f1-score  accuracy       time
# classifier
# KNeighborsClassifier    0.519075  0.477857  15.492502
# MLPClassifier           0.559259  0.503602  15.613716
# RandomForestClassifier  0.569432  0.520708  17.006049
# SVC                     0.573838  0.524682  15.586888
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print('Standard Deviations over 10 splits:')
res.groupby(['classifier']).std()[['f1-score', 'accuracy', 'time']]

# %% [markdown]
# ### Quaternary classification

# %%
params["classification"] = "quaternary"
params["classes"] = QAD_LABELS
y = labels["affect4-class"]
show_label_stats(params["classes"], y)
# Out:
#        labels  counts  percentage
# 0     Relaxed     215   30.758226
# 1      Stress     195   27.896996
# 2  RealStress     167   23.891273
# 3      Amused     122   17.453505

# %%
res, conf, models = make_nclassif_random_splits(x, y,
                    n_splits = params['n_splits'],
                    feature_selector = params['feature_selector'],
                    list_classifiers = list_classif,
                    random_seed = params['state_int'],
                    test_size = params['test_size'],
                    )
output(res, conf, list_classif, params)
if params["save_models"]:
    save_models(models, x, params)

print('Standard Deviations over 10 splits:')
res.groupby(['classifier']).std()[['f1-score', 'accuracy', 'time']]
# Out:
# Split  1/10
# Split  2/10
# Split  3/10
# Split  4/10
# Split  5/10
# Split  6/10
# Split  7/10
# Split  8/10
# Split  9/10
# Split 10/10
# Saving results to ../../stressid-dataset/../stressID/Classification/Results/20260103-145631_quaternary_10s&0.2_RFEf.21.csv and ../../stressid-dataset/../stressID/Classification/Results/20260103-145631_quaternary_10s&0.2_RFEf.21.avg.csv
#                         f1-score  accuracy       time
# classifier
# KNeighborsClassifier    0.388265  0.394466  15.866731
# MLPClassifier           0.404070  0.412533  15.919346
# RandomForestClassifier  0.442461  0.449205  15.966883
# SVC                     0.430201  0.428673  16.745174
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Standard Deviations over 10 splits:
#                         f1-score  accuracy      time
# classifier
# KNeighborsClassifier    0.033448  0.029883  2.638610
# MLPClassifier           0.026126  0.031211  2.377582
# RandomForestClassifier  0.039262  0.034330  2.408255
# SVC                     0.026594  0.028118  1.898016
