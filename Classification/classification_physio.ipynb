# %% [markdown]
# # Classification of Stress from Physiological data

# %%
# %matplotlib widget
import numpy as np
import scipy.io
import scipy.stats as stats
import matplotlib.pyplot as plt
import pandas as pd
import random
import time
from datetime import datetime

import os
from pathlib import Path
from IPython.display import display

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split, LeaveOneOut, GroupKFold
from sklearn.svm import LinearSVC, SVR, SVC
from sklearn.feature_selection import SelectFromModel
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import RFE
from sklearn.feature_selection import RFECV
from sklearn.metrics import balanced_accuracy_score, f1_score, ConfusionMatrixDisplay

from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.preprocessing import StandardScaler

from sklearn.utils import shuffle

from make_classification import avg_res, make_nclassif_random_splits

BASE_PATH = "../../stressid-dataset"
LABELS_SEPARATOR = ","
LABELS_FILENAME = "labels.csv"
FEATURES_SEPARATOR = ","
FEATURES_DIRECTORY = "../Reprod-Features-NK"
FEATURES_FILENAME = f"{FEATURES_DIRECTORY}/all_physiological_features.csv"
RESULTS_SEPARATOR = ";"
RESULTS_DIRECTORY = "results"
BIN_LABELS = ["NoStress", "Stress"]
TER_LABELS = ["Relaxed", "Stress", "RealStress"]
QAD_LABELS = ["Relaxed", "Stress", "RealStress", "Amused"]
ONNX_OPSET = 21
DEBUG = True

# %%
def make_results_filename(classification: str, splits: int, feature_selection: str | None, test_size: float, state_int: int) -> str:
    now = datetime.now()
    timestamp = now.strftime("%Y%m%d-%H%M%S")
    feature_selection = feature_selection if feature_selection is not None else "None"
    return f"{BASE_PATH}/{RESULTS_DIRECTORY}/{timestamp}_{classification}_{splits}s&{test_size}_{feature_selection}f.{state_int}"

def show_label_stats(labels: list[str], y: pd.Series):
    display(pd.DataFrame(
        {
            "labels": labels,
            "counts": y.value_counts().to_list(),
            "percentage": (y.value_counts(normalize=True) * 100).to_list(),
        }
    ))

def output(results: pd.DataFrame, conf_matrices: np.ndarray, classifiers: list, meta: dict):
    classification = meta['classification']
    n_splits = meta['n_splits']
    feature_selector = meta['feature_selector']
    test_size = meta['test_size']
    state_int = meta['state_int']
    labels = meta['classes']
    averages = avg_res(results)
    if meta['save_results']:
        res_file = make_results_filename(classification, n_splits, feature_selector, test_size, state_int) + ".csv"
        avg_file = make_results_filename(classification, n_splits, feature_selector, test_size, state_int) + ".avg.csv"
        print(f"Saving results to {res_file} and {avg_file}")
        results.to_csv(res_file, sep=RESULTS_SEPARATOR, index=True)
        averages.to_csv(avg_file, sep=RESULTS_SEPARATOR, index=True)

    # Show results
    if meta['show_averages']:
        display(averages)
    if meta['show_confusion_matrices']:
        for confusion_matrix, clf in zip(conf_matrices, classifiers):
            disp = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix, display_labels=labels)
            disp.plot(cmap=plt.cm.Blues)
            disp.ax_.set_title(clf.__class__.__name__)
            plt.show()


def save_models(classifiers: dict[str, Pipeline], x: pd.DataFrame, meta: dict):
    from skl2onnx import to_onnx
    from skl2onnx.common.data_types import FloatTensorType, Int32TensorType

    init_types = [("input", FloatTensorType([None,  x.shape[1]]))]
    final_types = [
        ("label", Int32TensorType([None, len(meta["classes"])])),
        ("probabilities", FloatTensorType([None, len(meta["classes"])])),
    ]

    if DEBUG:
        from skl2onnx import __max_supported_opset__, __version__
        print(f"skl2onnx version {__version__}, lastest opset supported: {__max_supported_opset__}")
        print(f"Initial types: {init_types}")
        print(f"Final types: {final_types}")
    for name, cls in classifiers.items():
        now = datetime.now()
        timestamp = now.strftime("%Y%m%d-%H%M%S")
        filename = f"{BASE_PATH}/{RESULTS_DIRECTORY}/{timestamp}_{name}_{meta['feature_selector']}f.onnx"
        onx = to_onnx(
            cls,
            initial_types=init_types,
            final_types=final_types,
            target_opset=ONNX_OPSET,
            options={"classification__zipmap": False},
        )
        with open(filename, "wb") as f:
            f.write(onx.SerializeToString())
        print(f"Model {name} saved to {filename}")

# %% [markdown]
# #### Import labels

# %%
labels = pd.read_csv(f"{BASE_PATH}/{LABELS_FILENAME}", sep=LABELS_SEPARATOR, header=0, index_col=0).dropna()
labels.head()
# Out:
#                 binary-stress  affect3-class
# subject/task
# 2ea4_Breathing              0              0
# 2ea4_Counting1              1              2
# 2ea4_Counting2              1              2
# 2ea4_Counting3              1              2
# 2ea4_Math                   1              2

# %% [markdown]
# # Classical approaches
#
# Several models are tested: Random Forests, K nearets neighbors, SVM, and Multi Layer Perceptron. All models are fitted 10 times on random splits, and the average scores over 10 repetitions are reported.
#
# The dimensionality of the features matrix can be reduced using PCA or Feature selection. Feature selection is performed using L1 penalty or Recursive Feature Elimination (RFE). The optimal number of features is determined using RFECV.

# %% [markdown]
# #### Import and prepare dataset
# We use handcrafted features.

# %%
X = pd.read_csv(f"{BASE_PATH}/{FEATURES_FILENAME}", sep=FEATURES_SEPARATOR, header=0, index_col=0)
display(X)
for col in X.columns:
    X[col] = X[col].astype(np.float32)
display(X)
# Out:
#                    meanHR      minHR       maxHR       sdHR      modeHR  \
# 2ea4_Baseline   63.430749  57.034221   79.575597   4.685361   22.541376
# 2ea4_Breathing  61.712623  45.871560   84.033613  11.009485   38.162054
# 2ea4_Counting1  70.973286  58.479532   82.872928   5.448858   24.393396
# 2ea4_Counting2  64.301095  56.285178   79.787234   5.497250   23.502056
# 2ea4_Counting3  66.253079  55.762082   80.645161   5.443328   24.883080
# ...                   ...        ...         ...        ...         ...
# y9z6_Relax      58.768320  50.933786   75.000000   4.024016   24.066214
# y9z6_Speaking   79.574294  61.601643  176.470588  27.277891  114.868946
# y9z6_Stroop     64.712598  58.027079   73.710074   3.844910   15.682994
# y9z6_Video1     60.061811  53.191489   75.757576   3.685925   22.566086
# y9z6_Video2     59.562842  52.631579  164.835165  11.134383  112.203586
#
#                       nNN       meanNN        SDSD        CVNN      SDNN  ...  \
# 2ea4_Baseline   62.000000   950.677419   41.894327   64.816310  0.068179  ...
# 2ea4_Breathing  59.666667  1002.893855  106.620821  173.316789  0.172817  ...
# 2ea4_Counting1  69.000000   850.550725   42.532503   67.603176  0.079482  ...
# 2ea4_Counting2  63.000000   939.587302   58.386027   76.102820  0.080996  ...
# 2ea4_Counting3  65.000000   911.661538   42.884190   74.003384  0.081174  ...
# ...                   ...          ...         ...         ...       ...  ...
# y9z6_Relax      58.000000  1025.475862   73.275208   66.397765  0.064748  ...
# y9z6_Speaking   73.000000   810.684932  171.499251  168.914413  0.208360  ...
# y9z6_Stroop     63.000000   930.412698   45.644284   54.586653  0.058669  ...
# y9z6_Video1     59.310345  1002.581395   59.116008   59.104060  0.058952  ...
# y9z6_Video2     57.966102  1023.543860  100.736662   93.855819  0.091697  ...
#
#                  min_scl  mean_scl    sd_scl       nSCR      aucSCR  \
# 2ea4_Baseline  -1.132743  0.022668  0.891539  10.000000 -302.978934
# 2ea4_Breathing -0.968230 -0.006435  0.951185   7.333333  120.038332
# 2ea4_Counting1 -2.159093  0.012778  0.827482   7.000000  -92.589522
# 2ea4_Counting2 -1.167276 -0.011765  0.937448   6.000000  315.591734
# 2ea4_Counting3 -1.494708 -0.015553  0.904099  12.000000  558.708830
# ...                  ...       ...       ...        ...         ...
# y9z6_Relax     -1.017887 -0.000668  0.990734   2.400000  122.464218
# y9z6_Speaking  -2.730086  0.022081  0.680286   5.000000  205.591732
# y9z6_Stroop    -1.291715 -0.029019  0.932817   5.000000  608.317194
# y9z6_Video1    -1.833577  0.002666  0.974272   3.103448    5.575997
# y9z6_Video2    -1.142737  0.001318  0.998102   2.033898  -18.621149
#
#                 meanAmpSCR  maxAmpSCR  meanRespSCR  sumAmpSCR  sumRespSCR
# 2ea4_Baseline     0.666899   1.475682     1.160000   6.668994   11.600000
# 2ea4_Breathing    0.651699   1.748524     1.126095   4.779126    7.882667
# 2ea4_Counting1    0.860715   2.091642     2.433429   6.025006   17.034000
# 2ea4_Counting2    0.543249   1.502306     1.810000   3.259493   10.860000
# 2ea4_Counting3    0.721123   1.743292     1.282167   8.653481   15.386000
# ...                    ...        ...          ...        ...         ...
# y9z6_Relax        0.197116   0.600114    13.550667   0.473079   32.521600
# y9z6_Speaking     0.939958   1.721442     2.791200   4.699788   13.956000
# y9z6_Stroop       0.320072   0.772637     1.639200   1.600359    8.196000
# y9z6_Video1       0.310237   1.061803     3.314667   0.962805   10.286897
# y9z6_Video2       0.110889   0.243203     6.086667   0.225537    9.284746
#
# [773 rows x 132 columns]
#                    meanHR      minHR       maxHR       sdHR      modeHR  \
# 2ea4_Baseline   63.430748  57.034222   79.575600   4.685360   22.541376
# 2ea4_Breathing  61.712624  45.871559   84.033615  11.009485   38.162052
# 2ea4_Counting1  70.973282  58.479530   82.872925   5.448858   24.393396
# 2ea4_Counting2  64.301094  56.285179   79.787231   5.497250   23.502056
# 2ea4_Counting3  66.253082  55.762081   80.645164   5.443328   24.883080
# ...                   ...        ...         ...        ...         ...
# y9z6_Relax      58.768322  50.933784   75.000000   4.024016   24.066214
# y9z6_Speaking   79.574295  61.601643  176.470581  27.277891  114.868942
# y9z6_Stroop     64.712601  58.027081   73.710075   3.844910   15.682995
# y9z6_Video1     60.061813  53.191490   75.757576   3.685925   22.566086
# y9z6_Video2     59.562843  52.631580  164.835159  11.134383  112.203583
#
#                       nNN       meanNN        SDSD        CVNN      SDNN  ...  \
# 2ea4_Baseline   62.000000   950.677429   41.894325   64.816307  0.068179  ...
# 2ea4_Breathing  59.666668  1002.893860  106.620819  173.316788  0.172817  ...
# 2ea4_Counting1  69.000000   850.550720   42.532505   67.603180  0.079482  ...
# 2ea4_Counting2  63.000000   939.587280   58.386028   76.102821  0.080996  ...
# 2ea4_Counting3  65.000000   911.661560   42.884190   74.003387  0.081174  ...
# ...                   ...          ...         ...         ...       ...  ...
# y9z6_Relax      58.000000  1025.475830   73.275208   66.397766  0.064748  ...
# y9z6_Speaking   73.000000   810.684937  171.499252  168.914413  0.208360  ...
# y9z6_Stroop     63.000000   930.412720   45.644283   54.586655  0.058669  ...
# y9z6_Video1     59.310345  1002.581421   59.116009   59.104061  0.058952  ...
# y9z6_Video2     57.966103  1023.543884  100.736664   93.855820  0.091697  ...
#
#                  min_scl  mean_scl    sd_scl       nSCR      aucSCR  \
# 2ea4_Baseline  -1.132743  0.022668  0.891540  10.000000 -302.978943
# 2ea4_Breathing -0.968230 -0.006435  0.951185   7.333333  120.038330
# 2ea4_Counting1 -2.159093  0.012778  0.827482   7.000000  -92.589523
# 2ea4_Counting2 -1.167276 -0.011765  0.937448   6.000000  315.591736
# 2ea4_Counting3 -1.494708 -0.015553  0.904099  12.000000  558.708801
# ...                  ...       ...       ...        ...         ...
# y9z6_Relax     -1.017887 -0.000668  0.990734   2.400000  122.464218
# y9z6_Speaking  -2.730086  0.022081  0.680286   5.000000  205.591736
# y9z6_Stroop    -1.291716 -0.029019  0.932817   5.000000  608.317200
# y9z6_Video1    -1.833577  0.002666  0.974272   3.103448    5.575997
# y9z6_Video2    -1.142737  0.001318  0.998102   2.033898  -18.621149
#
#                 meanAmpSCR  maxAmpSCR  meanRespSCR  sumAmpSCR  sumRespSCR
# 2ea4_Baseline     0.666899   1.475682     1.160000   6.668994   11.600000
# 2ea4_Breathing    0.651699   1.748524     1.126095   4.779126    7.882667
# 2ea4_Counting1    0.860715   2.091642     2.433429   6.025006   17.034000
# 2ea4_Counting2    0.543249   1.502306     1.810000   3.259493   10.860000
# 2ea4_Counting3    0.721123   1.743292     1.282167   8.653481   15.386000
# ...                    ...        ...          ...        ...         ...
# y9z6_Relax        0.197116   0.600114    13.550667   0.473079   32.521599
# y9z6_Speaking     0.939958   1.721442     2.791200   4.699788   13.956000
# y9z6_Stroop       0.320072   0.772637     1.639200   1.600359    8.196000
# y9z6_Video1       0.310237   1.061803     3.314667   0.962805   10.286897
# y9z6_Video2       0.110889   0.243203     6.086667   0.225537    9.284746
#
# [773 rows x 132 columns]

# %%
# Selecting rows that actually have entries in "labels" file
idx = list(X.merge(labels, left_index= True, right_index=True).index)
labels = labels.loc[idx]
x = X.loc[idx]

# %% [markdown]
# ### Parameter and models configuration

# %%
params = {
    "state_int": 21,
    "feature_selector": None,  ###  None, 'L1', 'PCA', or 'RFE' (ordered by speed)
    "test_size": 0.2,  # Paper value: 0.2
    "n_splits": 10,  # Paper value: 10
    "save_results": False,
    "show_averages": True,
    "show_confusion_matrices": True,
    "save_models": True,
}

list_classif = [RandomForestClassifier(max_depth=5, random_state=params['state_int']),
                KNeighborsClassifier(n_neighbors=3),
                SVC(gamma='auto', kernel='rbf', random_state=params['state_int']),
                MLPClassifier(max_iter=5000, random_state=params['state_int'], hidden_layer_sizes=[])
]

# %% [markdown]
# ### Binary classification

# %%
params['classification'] = 'binary'
params['classes'] = BIN_LABELS
y = labels['binary-stress']
show_label_stats(params['classes'], y)

res, conf, models = make_nclassif_random_splits(x, y,
                    n_splits = params['n_splits'],
                    feature_selector = params['feature_selector'],
                    list_classifiers = list_classif,
                    random_seed = params['state_int'],
                    test_size = params['test_size'],
                    )
output(res, conf, list_classif, params)
if params['save_models']:
    save_models(models, x, params)
# Out:
#      labels  counts  percentage
# 0  NoStress     367   52.503577
# 1    Stress     332   47.496423
# Split  1/10
# Split  2/10
# Split  3/10
# Split  4/10
# Split  5/10
# Split  6/10
# Split  7/10
# Split  8/10
# Split  9/10
# Split 10/10
#                         f1-score  accuracy      time
# classifier
# KNeighborsClassifier    0.656572  0.653141  0.976384
# MLPClassifier           0.718639  0.714975  1.082463
# RandomForestClassifier  0.745111  0.738752  1.157994
# SVC                     0.740376  0.734447  1.011029
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# skl2onnx version 1.19.1, lastest opset supported: 21
# Initial types: [('input', FloatTensorType(shape=[None, 132]))]
# Final types: [('label', Int32TensorType(shape=[None, 2])), ('probabilities', FloatTensorType(shape=[None, 2]))]
# ---------------------------------------------------------------------------
# MissingShapeCalculator                    Traceback (most recent call last)
# Cell In[19], line 15
#      13 output(res, conf, list_classif, params)
#      14 if params['save_models']:
# ---> 15     save_models(models, x, params)
#
# Cell In[14], line 61, in save_models(classifiers, x, meta)
#      59 timestamp = now.strftime("%Y%m%d-%H%M%S")
#      60 filename = f"{BASE_PATH}/{RESULTS_DIRECTORY}/{timestamp}_{name}_{meta['feature_selector']}f.onnx"
# ---> 61 onx = to_onnx(
#      62     cls,
#      63     initial_types=init_types,
#      64     final_types=final_types,
#      65     target_opset=ONNX_OPSET,
#      66     options={"classification__zipmap": False},
#      67 )
#      68 with open(filename, "wb") as f:
#      69     f.write(onx.SerializeToString())
#
# File ~/Documents/Research/PhDCourse/UXFrustrationRecognition/lib/python3.13/site-packages/skl2onnx/convert.py:312, in to_onnx(model, X, name, initial_types, target_opset, options, white_op, black_op, final_types, dtype, naming, model_optim, verbose)
#     310 if verbose >= 1:
#     311     print("[to_onnx] initial_types=%r" % initial_types)
# --> 312 model = convert_sklearn(
#     313     model,
#     314     initial_types=initial_types,
#     315     target_opset=target_opset,
#     316     name=name,
#     317     options=options,
#     318     white_op=white_op,
#     319     black_op=black_op,
#     320     final_types=final_types,
#     321     dtype=dtype,
#     322     verbose=verbose,
#     323     naming=naming,
#     324     model_optim=model_optim,
#     325 )
#     326 new_target_model = None
#     327 for op in model.opset_import:
#
# File ~/Documents/Research/PhDCourse/UXFrustrationRecognition/lib/python3.13/site-packages/skl2onnx/convert.py:211, in convert_sklearn(model, name, initial_types, doc_string, target_opset, custom_conversion_functions, custom_shape_calculators, custom_parsers, options, intermediate, white_op, black_op, final_types, dtype, naming, model_optim, verbose)
#     209 if verbose >= 1:
#     210     print("[convert_sklearn] convert_topology")
# --> 211 onnx_model = convert_topology(
#     212     topology,
#     213     name,
#     214     doc_string,
#     215     target_opset,
#     216     options=options,
#     217     remove_identity=model_optim and not intermediate,
#     218     verbose=verbose,
#     219 )
#     220 if verbose >= 1:
#     221     print("[convert_sklearn] end")
#
# File ~/Documents/Research/PhDCourse/UXFrustrationRecognition/lib/python3.13/site-packages/skl2onnx/common/_topology.py:1671, in convert_topology(topology, model_name, doc_string, target_opset, options, remove_identity, verbose)
#    1661 container = ModelComponentContainer(
#    1662     target_opset,
#    1663     options=options,
#    (...)   1667     verbose=verbose,
#    1668 )
#    1669 # Traverse the graph from roots to leaves
#    1670 # This loop could eventually be parallelized.
# -> 1671 topology.convert_operators(container=container, verbose=verbose)
#    1672 return make_model_from_container(
#    1673     container,
#    1674     remove_identity=remove_identity,
#    (...)   1678     model_name=model_name,
#    1679 )
#
# File ~/Documents/Research/PhDCourse/UXFrustrationRecognition/lib/python3.13/site-packages/skl2onnx/common/_topology.py:1347, in Topology.convert_operators(self, container, verbose)
#    1344 for variable in operator.outputs:
#    1345     _check_variable_out_(variable, operator)
# -> 1347 self.call_shape_calculator(operator)
#    1348 self.call_converter(operator, container, verbose=verbose)
#    1350 # If an operator contains a sequence of operators,
#    1351 # output variables are not necessarily known at this stage.
#
# File ~/Documents/Research/PhDCourse/UXFrustrationRecognition/lib/python3.13/site-packages/skl2onnx/common/_topology.py:1162, in Topology.call_shape_calculator(self, operator)
#    1160 else:
#    1161     logger.debug("[Shape2] call infer_types for %r", operator)
# -> 1162     operator.infer_types()
#
# File ~/Documents/Research/PhDCourse/UXFrustrationRecognition/lib/python3.13/site-packages/skl2onnx/common/_topology.py:628, in Operator.infer_types(self)
#     625 def infer_types(self):
#     626     # Invoke a core inference function
#     627     if self.type is None:
# --> 628         raise MissingShapeCalculator(
#     629             "Unable to find a shape calculator for type '{}'.".format(
#     630                 type(self.raw_operator)
#     631             )
#     632         )
#     633     try:
#     634         shape_calc = _registration.get_shape_calculator(self.type)
#
# MissingShapeCalculator: Unable to find a shape calculator for type '<class 'sklearn.impute._iterative.IterativeImputer'>'.
# It usually means the pipeline being converted contains a
# transformer or a predictor with no corresponding converter
# implemented in sklearn-onnx. If the converted is implemented
# in another library, you need to register
# the converted so that it can be used by sklearn-onnx (function
# update_registered_converter). If the model is not yet covered
# by sklearn-onnx, you may raise an issue to
# https://github.com/onnx/sklearn-onnx/issues
# to get the converter implemented or even contribute to the
# project. If the model is a custom model, a new converter must
# be implemented. Examples can be found in the gallery.

# %%
print('Standard Deviations over 10 splits:')
res.groupby(['classifier']).std()[['f1-score', 'accuracy', 'time']]

# %% [markdown]
# ### Ternary classification

# %%
params['classification'] = 'ternary'
params['classes'] = TER_LABELS
y = labels['affect3-class']
show_label_stats(params['classes'], y)

res, conf, models = make_nclassif_random_splits(x, y,
                    n_splits = params['n_splits'],
                    feature_selector = params['feature_selector'],
                    list_classifiers = list_classif,
                    random_seed = params['state_int'],
                    test_size = params['test_size'],
                    )
output(res, conf, list_classif, params)
if params["save_models"]:
    save_models(models, x, params)

# %%
print('Standard Deviations over 10 splits:')
res.groupby(['classifier']).std()[['f1-score', 'accuracy', 'time']]
