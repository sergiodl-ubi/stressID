# %% [markdown]
# # Classification of Stress from Physiological data

# %%
# %matplotlib widget
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.figure as figure
import pandas as pd
from datetime import datetime
import joblib

from IPython.display import display

from imblearn.over_sampling import ADASYN, SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, VotingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import LinearSVC, SVR, SVC
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.pipeline import Pipeline

from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, SimpleImputer
from sklearn.preprocessing import StandardScaler, MaxAbsScaler, RobustScaler
from sklearn.feature_selection import RFECV

from make_classification import avg_res, make_nclassif_random_splits, make_nclassif_kfold

BASE_PATH = "../../stressid-dataset"
LABELS_SEPARATOR = ","
LABELS_FILENAME = "../stressID/labels.csv"
FEATURES_SEPARATOR = ","
FEATURES_DIRECTORY = "../Reprod-Features-StdSubject"
# FEATURES_FILENAME = f"{FEATURES_DIRECTORY}/all_physiological_features.csv"
FEATURES_FILENAME = f"{FEATURES_DIRECTORY}/ecg_eda_features.csv"
RESULTS_SEPARATOR = ";"
RESULTS_DIRECTORY = "../stressID/Classification/Results_StdSubject_Opt"
BIN_LABELS = ["NoStress", "Stress"]
TER_LABELS = ["Relaxed", "Stress", "RealStress"]
QAD_LABELS = ["Relaxed", "Stress", "RealStress", "Amused"]
DEBUG = True
FLOAT_TYPE = np.float64

# %%
def make_results_filename(classification: str, splits: int, feature_selection: str | None, test_size: float, state_int: int) -> str:
    now = datetime.now()
    timestamp = now.strftime("%Y%m%d-%H%M%S")
    feature_selection = feature_selection if feature_selection is not None else "None"
    return f"{BASE_PATH}/{RESULTS_DIRECTORY}/{timestamp}_{classification}_{splits}s&{test_size}_{feature_selection}f.{state_int}"

def show_label_stats(labels: list[str], y: pd.Series):
    display(pd.DataFrame(
        {
            "labels": labels,
            "counts": y.value_counts().to_list(),
            "percentage": (y.value_counts(normalize=True) * 100).to_list(),
        }
    ))

def output(results: pd.DataFrame, conf_matrices: dict[str, np.ndarray], meta: dict):
    classification = meta['classification']
    n_splits = meta['n_splits']
    feature_selector = meta['feature_selector']
    test_size = meta['test_size']
    state_int = meta['state_int']
    labels = meta['classes']
    averages = avg_res(results)
    if meta['save_results']:
        res_file = make_results_filename(classification, n_splits, feature_selector, test_size, state_int) + ".csv"
        avg_file = make_results_filename(classification, n_splits, feature_selector, test_size, state_int) + ".avg.csv"
        print(f"Saving results to {res_file}, {avg_file}")
        results.to_csv(res_file, sep=RESULTS_SEPARATOR, index=True)
        averages.to_csv(avg_file, sep=RESULTS_SEPARATOR, index=True)

    # Show results
    if meta['show_averages']:
        display(averages)
    if meta['show_confusion_matrices']:
        cm_file = make_results_filename(classification, n_splits, feature_selector, test_size, state_int) + ".CM.png"
        ncms = len(conf_matrices)
        pairs = [(name, cm) for name, cm in conf_matrices.items()]
        nrows = (ncms // 2) + (ncms % 2)
        fig, axes = plt.subplots(nrows, 2, figsize=(8, nrows*4))
        for (name, cm), ax in zip(pairs, axes.ravel()):
            disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
            disp.plot(cmap=plt.cm.Blues, ax=ax, colorbar=False)
            ax.set_title(name)
        fig.suptitle("Confusion Matrices")
        plt.tight_layout()
        if meta["save_results"]:
            print(f"Saving confusion matrix to {cm_file}")
            plt.savefig(cm_file, dpi=300, format="png")
        plt.show()


def save_models(classifiers: dict[str, Pipeline], meta: dict):
    classification = meta["classification"]
    for name, cls in classifiers.items():
        now = datetime.now()
        timestamp = now.strftime("%Y%m%d-%H%M%S")
        filename = (
            f"{BASE_PATH}/{RESULTS_DIRECTORY}/{timestamp}_{classification}_{name}_{meta['feature_selector']}f.joblib"
        )
        joblib.dump(cls, filename)
        print(f"Model {name} saved to {filename}")

# %% [markdown]
# #### Import labels

# %%
labels = pd.read_csv(f"{BASE_PATH}/{LABELS_FILENAME}", sep=LABELS_SEPARATOR, header=0, index_col=0).dropna()
labels[:15]
# Out:
#                 binary-stress  affect3-class  affect4-class
# subject/task
# 2ea4_Breathing              0              0              0
# 2ea4_Counting1              1              2              2
# 2ea4_Counting2              1              2              2
# 2ea4_Counting3              1              2              2
# 2ea4_Math                   1              2              2
# 2ea4_Reading                0              0              3
# 2ea4_Relax                  0              0              0
# 2ea4_Speaking               1              2              2
# 2ea4_Stroop                 0              0              3
# 2ea4_Video1                 0              0              3
# 2ea4_Video2                 0              0              3
# 2hpu_Breathing              0              0              0
# 2hpu_Counting1              1              2              1
# 2hpu_Counting2              1              1              1
# 2hpu_Counting3              1              2              1

# %% [markdown]
# # Classical approaches
#
# Several models are tested: Random Forests, K nearets neighbors, SVM, and Multi Layer Perceptron. All models are fitted 10 times on random splits, and the average scores over 10 repetitions are reported.
#
# The dimensionality of the features matrix can be reduced using PCA or Feature selection. Feature selection is performed using L1 penalty or Recursive Feature Elimination (RFE). The optimal number of features is determined using RFECV.

# %% [markdown]
# #### Import and prepare dataset
# We use handcrafted features.

# %%
X = pd.read_csv(f"{BASE_PATH}/{FEATURES_FILENAME}", sep=FEATURES_SEPARATOR, header=0, index_col=0)
display(X)
for col in X.columns:
    X[col] = X[col].astype(FLOAT_TYPE)
display(X)
# Out:
#                    meanHR      minHR       maxHR       sdHR      modeHR  \
# 2ea4_Baseline   63.430749  57.034221   79.575597   4.685361   22.541376
# 2ea4_Breathing  61.712623  45.871560   84.033613  11.009485   38.162054
# 2ea4_Counting1  70.973286  58.479532   82.872928   5.448858   24.393396
# 2ea4_Counting2  64.301095  56.285178   79.787234   5.497250   23.502056
# 2ea4_Counting3  66.253079  55.762082   80.645161   5.443328   24.883080
# ...                   ...        ...         ...        ...         ...
# y9z6_Relax      58.768320  50.933786   75.000000   4.024016   24.066214
# y9z6_Speaking   79.574294  61.601643  176.470588  27.277891  114.868946
# y9z6_Stroop     64.712598  58.027079   73.710074   3.844910   15.682994
# y9z6_Video1     60.061811  53.191489   75.757576   3.685925   22.566086
# y9z6_Video2     59.562842  52.631579  164.835165  11.134383  112.203586
#
#                       nNN       meanNN        SDSD        CVNN      SDNN  ...  \
# 2ea4_Baseline   62.000000   950.677419   41.894327   64.816310  0.068179  ...
# 2ea4_Breathing  59.666667  1002.893855  106.620821  173.316789  0.172817  ...
# 2ea4_Counting1  69.000000   850.550725   42.532503   67.603176  0.079482  ...
# 2ea4_Counting2  63.000000   939.587302   58.386027   76.102820  0.080996  ...
# 2ea4_Counting3  65.000000   911.661538   42.884190   74.003384  0.081174  ...
# ...                   ...          ...         ...         ...       ...  ...
# y9z6_Relax      58.000000  1025.475862   73.275208   66.397765  0.064748  ...
# y9z6_Speaking   73.000000   810.684932  171.499251  168.914413  0.208360  ...
# y9z6_Stroop     63.000000   930.412698   45.644284   54.586653  0.058669  ...
# y9z6_Video1     59.310345  1002.581395   59.116008   59.104060  0.058952  ...
# y9z6_Video2     57.966102  1023.543860  100.736662   93.855819  0.091697  ...
#
#                  min_scl  mean_scl    sd_scl       nSCR      aucSCR  \
# 2ea4_Baseline  -0.669062 -0.018561  0.501941  10.000000 -170.578482
# 2ea4_Breathing -1.351739 -0.978852  0.368773   7.333333   46.538691
# 2ea4_Counting1  0.187387  1.475848  0.490903   7.000000  -54.928645
# 2ea4_Counting2  0.231078  1.011078  0.632802   6.000000  213.032840
# 2ea4_Counting3  0.416633  0.981071  0.345000  12.000000  213.200619
# ...                  ...       ...       ...        ...         ...
# y9z6_Relax     -0.883150 -0.217756  0.648069   2.400000   80.107583
# y9z6_Speaking   0.463555  1.163685  0.173059   5.000000   52.300939
# y9z6_Stroop     0.500465  0.907920  0.301008   5.000000  196.295751
# y9z6_Video1    -1.351475 -0.918952  0.229488   3.103448    1.313413
# y9z6_Video2    -1.453739 -0.832914  0.541624   2.033898  -10.104829
#
#                 meanAmpSCR  maxAmpSCR  meanRespSCR  sumAmpSCR  sumRespSCR
# 2ea4_Baseline     0.375467   0.830815     1.160000   3.754673   11.600000
# 2ea4_Breathing    0.252663   0.677900     1.126095   1.852861    7.882667
# 2ea4_Counting1    0.510618   1.240865     2.433429   3.574329   17.034000
# 2ea4_Counting2    0.366707   1.014097     1.810000   2.200245   10.860000
# 2ea4_Counting3    0.275177   0.665232     1.282167   3.302127   15.386000
# ...                    ...        ...          ...        ...         ...
# y9z6_Relax        0.128940   0.392553    13.550667   0.309456   32.521600
# y9z6_Speaking     0.239118   0.437921     2.791200   1.195589   13.956000
# y9z6_Stroop       0.103283   0.249320     1.639200   0.516414    8.196000
# y9z6_Video1       0.073076   0.250105     3.314667   0.226786   10.286897
# y9z6_Video2       0.060174   0.131975     6.086667   0.122388    9.284746
#
# [773 rows x 70 columns]
#                    meanHR      minHR       maxHR       sdHR      modeHR  \
# 2ea4_Baseline   63.430749  57.034221   79.575597   4.685361   22.541376
# 2ea4_Breathing  61.712623  45.871560   84.033613  11.009485   38.162054
# 2ea4_Counting1  70.973286  58.479532   82.872928   5.448858   24.393396
# 2ea4_Counting2  64.301095  56.285178   79.787234   5.497250   23.502056
# 2ea4_Counting3  66.253079  55.762082   80.645161   5.443328   24.883080
# ...                   ...        ...         ...        ...         ...
# y9z6_Relax      58.768320  50.933786   75.000000   4.024016   24.066214
# y9z6_Speaking   79.574294  61.601643  176.470588  27.277891  114.868946
# y9z6_Stroop     64.712598  58.027079   73.710074   3.844910   15.682994
# y9z6_Video1     60.061811  53.191489   75.757576   3.685925   22.566086
# y9z6_Video2     59.562842  52.631579  164.835165  11.134383  112.203586
#
#                       nNN       meanNN        SDSD        CVNN      SDNN  ...  \
# 2ea4_Baseline   62.000000   950.677419   41.894327   64.816310  0.068179  ...
# 2ea4_Breathing  59.666667  1002.893855  106.620821  173.316789  0.172817  ...
# 2ea4_Counting1  69.000000   850.550725   42.532503   67.603176  0.079482  ...
# 2ea4_Counting2  63.000000   939.587302   58.386027   76.102820  0.080996  ...
# 2ea4_Counting3  65.000000   911.661538   42.884190   74.003384  0.081174  ...
# ...                   ...          ...         ...         ...       ...  ...
# y9z6_Relax      58.000000  1025.475862   73.275208   66.397765  0.064748  ...
# y9z6_Speaking   73.000000   810.684932  171.499251  168.914413  0.208360  ...
# y9z6_Stroop     63.000000   930.412698   45.644284   54.586653  0.058669  ...
# y9z6_Video1     59.310345  1002.581395   59.116008   59.104060  0.058952  ...
# y9z6_Video2     57.966102  1023.543860  100.736662   93.855819  0.091697  ...
#
#                  min_scl  mean_scl    sd_scl       nSCR      aucSCR  \
# 2ea4_Baseline  -0.669062 -0.018561  0.501941  10.000000 -170.578482
# 2ea4_Breathing -1.351739 -0.978852  0.368773   7.333333   46.538691
# 2ea4_Counting1  0.187387  1.475848  0.490903   7.000000  -54.928645
# 2ea4_Counting2  0.231078  1.011078  0.632802   6.000000  213.032840
# 2ea4_Counting3  0.416633  0.981071  0.345000  12.000000  213.200619
# ...                  ...       ...       ...        ...         ...
# y9z6_Relax     -0.883150 -0.217756  0.648069   2.400000   80.107583
# y9z6_Speaking   0.463555  1.163685  0.173059   5.000000   52.300939
# y9z6_Stroop     0.500465  0.907920  0.301008   5.000000  196.295751
# y9z6_Video1    -1.351475 -0.918952  0.229488   3.103448    1.313413
# y9z6_Video2    -1.453739 -0.832914  0.541624   2.033898  -10.104829
#
#                 meanAmpSCR  maxAmpSCR  meanRespSCR  sumAmpSCR  sumRespSCR
# 2ea4_Baseline     0.375467   0.830815     1.160000   3.754673   11.600000
# 2ea4_Breathing    0.252663   0.677900     1.126095   1.852861    7.882667
# 2ea4_Counting1    0.510618   1.240865     2.433429   3.574329   17.034000
# 2ea4_Counting2    0.366707   1.014097     1.810000   2.200245   10.860000
# 2ea4_Counting3    0.275177   0.665232     1.282167   3.302127   15.386000
# ...                    ...        ...          ...        ...         ...
# y9z6_Relax        0.128940   0.392553    13.550667   0.309456   32.521600
# y9z6_Speaking     0.239118   0.437921     2.791200   1.195589   13.956000
# y9z6_Stroop       0.103283   0.249320     1.639200   0.516414    8.196000
# y9z6_Video1       0.073076   0.250105     3.314667   0.226786   10.286897
# y9z6_Video2       0.060174   0.131975     6.086667   0.122388    9.284746
#
# [773 rows x 70 columns]

# %%
# Selecting rows that actually have entries in "labels" file
idx = list(X.merge(labels, left_index= True, right_index=True).index)
labels = labels.loc[idx]
x = X.loc[idx]

# %% [markdown]
# ### Parameter and models configuration

# %%
# Hyperparameters tunning

tunning_for = {
    "RandomForest": False,
    "KNN": False,
    "SVM": False,
    "MLP": False,
    "LogisticRegression": False,
}
randomized = False

if any(tunning_for.values()):
    from sklearn.model_selection import RandomizedSearchCV, GridSearchCV, train_test_split
    from scipy.stats import uniform

    search_class = RandomizedSearchCV if randomized else GridSearchCV

    state_int = 21
    y = labels["affect3-class"]

    ada = ADASYN(random_state=state_int, sampling_strategy={0: 400, 1: 400, 2: 400})
    x_in, y_in = ada.fit_resample(x, y)
    print("Resampled dataset")
    show_label_stats(TER_LABELS, y_in)

    def make_pipeline(model):
        return Pipeline(
            [
                ("imputer", IterativeImputer),
                ("scaler", StandardScaler),
                ("feature_selection", RFECV(RandomForestClassifier(max_depth=5), step=2, cv=2)),
                ("cls", model),
            ]
        )

    x_train, x_test, y_train, y_test = train_test_split(
        x_in, y_in, test_size=0.2, random_state=state_int
    )

    if tunning_for["RandomForest"]:
        print("Tunning RandomForestClassifier...")
        param_grid = {
            "cls__n_estimators": [100, 200, 300, 350, 400, 450, 500],
            "cls__max_depth": [None, 5, 10, 15, 20, 30, 40, 50],
            "cls__min_samples_split": [2, 5, 10],
            "cls__min_samples_leaf": [1, 2, 4],
            "cls__max_features": ["sqrt", "log2", None],
            "cls__bootstrap": [True, False],
        }
        search = search_class(
            make_pipeline(RandomForestClassifier()),
            param_grid,
        )
        search.fit(x_train, y_train)
        print(f"Best parameters found for RF: {search.best_params_}")
        print(f"Best score: {search.best_score_:.3f}")
        best_model = search.best_estimator_
        accuracy = best_model.score(x_test, y_test)
        print(f"Test set accuracy: {accuracy:.3f}")

    if tunning_for["KNN"]:
        print("Tunning KNeighborsClassifier...")
        param_grid = {
            "cls__n_neighbors": list(range(2, 21, 1)),
            "cls__weights": ["uniform", "distance"],
            "cls__p": [1, 2],
        }
        search = search_class(make_pipeline(KNeighborsClassifier()), param_grid)
        search.fit(x_train, y_train)
        print(f"Best parameters found for KNN: {search.best_params_}")
        print(f"Best score: {search.best_score_:.3f}")
        best_model = search.best_estimator_
        accuracy = best_model.score(x_test, y_test)
        print(f"Test set accuracy: {accuracy:.3f}")

    if tunning_for["SVM"]:
        print("Tunning SVM...")
        param_grid = {
            "cls__C": [0.1, 1, 10, 100, 1000, 5000, 10000],
            "cls__gamma": [
                "auto",
                "scale",
            ],
            "cls__kernel": [
                "rbf",
            ],
        }
        search = search_class(make_pipeline(SVC()), param_grid)
        search.fit(x_train, y_train)
        print(f"Best parameters found for SVM: {search.best_params_}")
        print(f"Best score: {search.best_score_:.3f}")
        best_model = search.best_estimator_
        accuracy = best_model.score(x_test, y_test)
        print(f"Test set accuracy: {accuracy:.3f}")

    if tunning_for["MLP"]:
        print("Tunning MLP...")
        param_grid = {
            "cls__hidden_layer_sizes": [
                (),
                (50,),
                (100,),
                (25, 25),
                (50, 50),
                (25, 25, 25),
                (50, 25, 25),
                (20, 50, 20),
            ],
            "cls__activation": ["tanh", "relu"],
            "cls__learning_rate_init": [0.0001, 0.0002, 0.0005, 0.0008, 0.001, 0.002, 0.005, 0.008, 0.01],
            "cls__alpha": [0.0001, 0.0002, 0.0005, 0.0008, 0.001, 0.002, 0.005, 0.008, 0.01],
        }
        search = search_class(
            make_pipeline(MLPClassifier(max_iter=10000)),
            param_grid,
        )
        search.fit(x_train, y_train)
        print(f"Best parameters found for MLP: {search.best_params_}")
        print(f"Best score: {search.best_score_:.3f}")
        best_model = search.best_estimator_
        accuracy = best_model.score(x_test, y_test)
        print(f"Test set accuracy: {accuracy:.3f}")

    if tunning_for["LogisticRegression"]:
        print("Tunning LogisticRegression...")

        print("\n\nlbfgs\n\n")
        param_grid = {
            "cls__C": np.logspace(-4, 4, 20),
            "cls__penalty": ["l2", None],
            "cls__solver": ["lbfgs", "newton-cg"],
        }
        search = search_class(make_pipeline(LogisticRegression(max_iter=10000)), param_grid)
        search.fit(x_train, y_train)
        print(f"Best parameters found for LogisticRegression: {search.best_params_}")
        print(f"Best score: {search.best_score_:.3f}")
        best_model = search.best_estimator_
        accuracy = best_model.score(x_test, y_test)
        print(f"Test set accuracy: {accuracy:.3f}")

        print("\n\nsaga\n\n")
        param_grid = {
            "cls__C": np.logspace(-4, 4, 20),
            "cls__penalty": ["l1", "l2", "elasticnet", None],
            "cls__solver": ["saga"],
        }
        search = search_class(make_pipeline(LogisticRegression(max_iter=10000)), param_grid)
        search.fit(x_train, y_train)
        print(f"Best parameters found for LogisticRegression: {search.best_params_}")
        print(f"Best score: {search.best_score_:.3f}")
        best_model = search.best_estimator_
        accuracy = best_model.score(x_test, y_test)
        print(f"Test set accuracy: {accuracy:.3f}")


    raise Exception("Tunning finished. Please, set the best parameters found.")

# %%
params = {
    "state_int": 21,
    "feature_selector": "RFE",  ###  None, 'PCA', 'L1', or 'RFE' (ordered by speed)
    "test_size": 0.2,  # Paper value: 0.2
    "n_splits": 10,  # Paper value: 10
    "data_augmentation": False,
    "show_averages": True,
    "show_confusion_matrices": True,
    "save_models": False,
    "save_results": False,
    "verbose": False,
}

validations = {
    'holdout': True,
    'kfold': True
}

list_classif = [
    # RandomForestClassifier(max_depth=5, random_state=params["state_int"]), # Original
    RandomForestClassifier(bootstrap=True, max_depth=40, max_features="log2", min_samples_leaf=1, min_samples_split=2, n_estimators=450, random_state=params["state_int"]),
    # LogisticRegression(max_iter=10000),
    KNeighborsClassifier(n_neighbors=2, p=1, weights="distance"),
    # SVC(gamma="auto", kernel="rbf", random_state=params["state_int"], probability=True), # Original
    SVC(C=1000, gamma="auto", kernel="rbf", random_state=params["state_int"], probability=True),
    # MLPClassifier(max_iter=5000, hidden_layer_sizes=[], random_state=params["state_int"]), # Original
    MLPClassifier(activation="tanh", alpha=0.008, hidden_layer_sizes=(100,), learning_rate_init=0.005, max_iter=10000, random_state=params["state_int"]),
]

# %% [markdown]
# ### Binary classification

# %%
params['classification'] = 'binary'
params['classes'] = BIN_LABELS
y = labels['binary-stress']
show_label_stats(params['classes'], y)

if params["data_augmentation"]:
    ada = ADASYN(random_state=params["state_int"], sampling_strategy={0: 650, 1:650})
    x_in, y_in = ada.fit_resample(x, y)
    print("Resampled dataset")
    show_label_stats(params["classes"], y_in)
else:
    x_in = x.copy()
    y_in = y.copy()

    # Visualise class distribution
    plt.figure(figsize=(12, 6))

    bin_stats = pd.DataFrame(
        {
            "Value": y_in.values,
            "Subject": [idx.split("_")[0] for idx in y_in.index],
            "Task": [idx.split("_")[1] for idx in y_in.index],
        },
        index=y_in.index,
    )
    for cls_id, cls_name in enumerate(params["classes"]):
        bin_stats[cls_name] = [value == cls_id for value in y_in]

    tasks = sorted(bin_stats['Task'].unique())
    x_positions = np.arange(len(tasks))
    width = 0.35

    # Plot bars and scatter points for each class
    for i, class_name in enumerate(params["classes"]):
        counts = bin_stats.groupby('Task')[class_name].sum()
        bars = plt.bar(x_positions + (i-0.5)*width, [counts[task] for task in tasks], width,
                        label=class_name, alpha=0.7)

    plt.xlabel('Task')
    plt.ylabel('Count')
    plt.title('Number of instances per class by Task')
    plt.xticks(x_positions, tasks, rotation=45)
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

    print("\nInstances count per task:")
    display(bin_stats.groupby('Task')[params["classes"]].sum())
# Out:
#      labels  counts  percentage
# 0  NoStress     367   52.503577
# 1    Stress     332   47.496423
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Instances count per task:
#            NoStress  Stress
# Task
# Breathing        53      11
# Counting1        22      42
# Counting2        15      49
# Counting3        19      44
# Math             21      43
# Reading          29      35
# Relax            54       8
# Speaking         21      43
# Stroop           15      49
# Video1           45      18
# Video2           38      25

# %%
# 10 random splits holdout
if validations['holdout']:
    res, conf, models, probs_dict = make_nclassif_random_splits(
        x_in,
        y_in,
        n_splits=params["n_splits"],
        feature_selector=params["feature_selector"],
        list_classifiers=list_classif,
        random_seed=params["state_int"],
        test_size=params["test_size"],
        verbose=params["verbose"],
        useStratification=False,
    )
    output(res, conf, params)
    if params["save_models"]:
        save_models(models, params)

    print(f"Standard Deviations {params['n_splits']} holdouts:")
    display(res.groupby(["classifier"]).std()[["f1-score", "accuracy", "time"]])

    if not params["data_augmentation"]:
        for model_name, probs_df in probs_dict.items():
            agg_cols = {}
            for cls_idx, cls_name in enumerate(params["classes"]):
                agg_cols[cls_idx] = cls_name
            probs_df["Subject"] = [idx.split("_")[0] for idx in probs_df.index]
            probs_df["Task"] = [idx.split("_")[1] for idx in probs_df.index]
            probs_dict[model_name] = probs_df.rename(columns=agg_cols).reset_index(drop=True)
# Out:
# Split  1/10
# Split  2/10
# Split  3/10
# Split  4/10
# Split  5/10
# Split  6/10
# Split  7/10
# Split  8/10
# Split  9/10
# Split 10/10
#                         f1-score  accuracy      time
# classifier
# KNeighborsClassifier    0.659093  0.655916  7.289411
# MLPClassifier_HLs(100)  0.670722  0.667417  7.684086
# RandomForestClassifier  0.735890  0.731192  8.108772
# SVC                     0.642910  0.640425  7.540874
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Standard Deviations 10 holdouts:
#                         f1-score  accuracy      time
# classifier
# KNeighborsClassifier     0.04558  0.048136  1.085760
# MLPClassifier_HLs(100)   0.03813  0.042475  0.765707
# RandomForestClassifier   0.03446  0.033479  1.112429
# SVC                      0.03796  0.039955  0.927762

# %%
if not params["data_augmentation"]:
    for model_name, probs_df in probs_dict.items():
        print(f"\n{model_name}")
        plt.figure(figsize=(12, 6))

        tasks = sorted(probs_df['Task'].unique())
        x_positions = np.arange(len(tasks))
        width = 0.35

        # Plot bars and scatter points for each class
        for i, class_name in enumerate(params["classes"]):
            means = probs_df.groupby('Task')[class_name].mean()
            bars = plt.bar(x_positions + (i-0.5)*width, [means[task] for task in tasks], width,
                        label=class_name, alpha=0.7)

            # Add scatter points
            for j, task in enumerate(tasks):
                task_data = probs_df[probs_df['Task'] == task][class_name]
                x_jitter = np.random.normal(0, 0.04, size=len(task_data))
                plt.scatter(np.repeat(x_positions[j] + (i-0.5)*width, len(task_data)) + x_jitter,
                        task_data, color='black', alpha=0.1, s=30)

        plt.xlabel('Task')
        plt.ylabel('Probability')
        plt.title(f'Class Probabilities by Task - {model_name}')
        plt.xticks(x_positions, tasks, rotation=45)
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.ylim(-0.05, 1.05)
        plt.tight_layout()
        plt.show()

        # Summary
        agg_cols = {}
        for cls_name in params["classes"]:
            agg_cols[cls_name] = ["mean", "count", "std"]
        probs_stats = probs_df.groupby("Task").agg(agg_cols)
        display(probs_stats)
# Out:
# RandomForestClassifier
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
#            NoStress                    Stress
#                mean count       std      mean count       std
# Task
# Breathing  0.735864   108  0.102166  0.264136   108  0.102166
# Counting1  0.316488   112  0.135184  0.683512   112  0.135184
# Counting2  0.336931   147  0.154622  0.663069   147  0.154622
# Counting3  0.371349   131  0.164080  0.628651   131  0.164080
# Math       0.371940   118  0.155113  0.628060   118  0.155113
# Reading    0.341963   120  0.135842  0.658037   120  0.135842
# Relax      0.665365   128  0.131315  0.334635   128  0.131315
# Speaking   0.369099   127  0.161239  0.630901   127  0.161239
# Stroop     0.346594   153  0.129052  0.653406   153  0.129052
# Video1     0.677698   111  0.127417  0.322302   111  0.127417
# Video2     0.637257   145  0.107183  0.362743   145  0.107183
# KNeighborsClassifier
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
#            NoStress                    Stress
#                mean count       std      mean count       std
# Task
# Breathing  0.801688   108  0.277354  0.198312   108  0.277354
# Counting1  0.269830   112  0.334696  0.730170   112  0.334696
# Counting2  0.307501   147  0.359743  0.692499   147  0.359743
# Counting3  0.382171   131  0.375861  0.617829   131  0.375861
# Math       0.362454   118  0.374520  0.637546   118  0.374520
# Reading    0.261184   120  0.328667  0.738816   120  0.328667
# Relax      0.571178   128  0.367767  0.428822   128  0.367767
# Speaking   0.365339   127  0.384534  0.634661   127  0.384534
# Stroop     0.339003   153  0.383616  0.660997   153  0.383616
# Video1     0.690609   111  0.341490  0.309391   111  0.341490
# Video2     0.713640   145  0.303739  0.286360   145  0.303739
# SVC
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
#            NoStress                    Stress
#                mean count       std      mean count       std
# Task
# Breathing  0.634974   108  0.165498  0.365026   108  0.165498
# Counting1  0.391291   112  0.153870  0.608709   112  0.153870
# Counting2  0.414477   147  0.159365  0.585523   147  0.159365
# Counting3  0.456356   131  0.172621  0.543644   131  0.172621
# Math       0.440820   118  0.179045  0.559180   118  0.179045
# Reading    0.410692   120  0.166068  0.589308   120  0.166068
# Relax      0.531139   128  0.180955  0.468861   128  0.180955
# Speaking   0.439812   127  0.148718  0.560188   127  0.148718
# Stroop     0.421627   153  0.157715  0.578373   153  0.157715
# Video1     0.581738   111  0.140014  0.418262   111  0.140014
# Video2     0.542822   145  0.153438  0.457178   145  0.153438
# MLPClassifier_HLs(100)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
#            NoStress                    Stress
#                mean count       std      mean count       std
# Task
# Breathing  0.853269   108  0.279546  0.146731   108  0.279546
# Counting1  0.224317   112  0.339676  0.775683   112  0.339676
# Counting2  0.269083   147  0.349411  0.730917   147  0.349411
# Counting3  0.325365   131  0.380653  0.674635   131  0.380653
# Math       0.302509   118  0.399898  0.697491   118  0.399898
# Reading    0.218195   120  0.329057  0.781805   120  0.329057
# Relax      0.697337   128  0.364541  0.302663   128  0.364541
# Speaking   0.354897   127  0.415576  0.645103   127  0.415576
# Stroop     0.289797   153  0.377013  0.710203   153  0.377013
# Video1     0.706730   111  0.363148  0.293270   111  0.363148
# Video2     0.705312   145  0.369392  0.294688   145  0.369392

# %%
# 5-fold cross-validation
if validations['kfold']:
    res, conf, models, probs_dict = make_nclassif_kfold(
        x_in,
        y_in,
        feature_selector=params["feature_selector"],
        list_classifiers=list_classif,
        random_seed=params["state_int"],
        verbose=params["verbose"],
        stratified=False,
    )
    output(res, conf, params)
    if params["save_models"]:
        save_models(models, params)

    print("Standard Deviations 5-folds cross-validation:")
    display(res.groupby(["classifier"]).std()[["f1-score", "accuracy", "time"]])

    if not params["data_augmentation"]:
        for model_name, probs_df in probs_dict.items():
            agg_cols = {}
            for cls_idx, cls_name in enumerate(params["classes"]):
                agg_cols[cls_idx] = cls_name
            probs_df["Subject"] = [idx.split("_")[0] for idx in probs_df.index]
            probs_df["Task"] = [idx.split("_")[1] for idx in probs_df.index]
            probs_dict[model_name] = probs_df.rename(columns=agg_cols).reset_index(drop=True)
# Out:
# Fold 1/5
# /Users/sergio-de/Documents/Research/PhDCourse/UXFrustrationRecognition/lib/python3.13/site-packages/numpy/linalg/_linalg.py:3026: RuntimeWarning: overflow encountered in dot
#   return dot(A, dot(B, C), out=out)
# /Users/sergio-de/Documents/Research/PhDCourse/UXFrustrationRecognition/lib/python3.13/site-packages/sklearn/linear_model/_bayes.py:291: RuntimeWarning: overflow encountered in dot
#   XT_y = np.dot(X.T, y)
# /Users/sergio-de/Documents/Research/PhDCourse/UXFrustrationRecognition/lib/python3.13/site-packages/numpy/linalg/_linalg.py:3026: RuntimeWarning: overflow encountered in dot
#   return dot(A, dot(B, C), out=out)
# /Users/sergio-de/Documents/Research/PhDCourse/UXFrustrationRecognition/lib/python3.13/site-packages/numpy/linalg/_linalg.py:3026: RuntimeWarning: overflow encountered in dot
#   return dot(A, dot(B, C), out=out)
# /Users/sergio-de/Documents/Research/PhDCourse/UXFrustrationRecognition/lib/python3.13/site-packages/numpy/linalg/_linalg.py:3026: RuntimeWarning: overflow encountered in dot
#   return dot(A, dot(B, C), out=out)
# Fold 2/5
# Fold 3/5
# Fold 4/5
# Fold 5/5
#                         f1-score  accuracy      time
# classifier
# KNeighborsClassifier    0.666325  0.664667  8.494447
# MLPClassifier_HLs(100)  0.685123  0.684589  8.240586
# RandomForestClassifier  0.715855  0.715311  8.943779
# SVC                     0.665912  0.664929  8.990936
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Standard Deviations 5-folds cross-validation:
#                         f1-score  accuracy      time
# classifier
# KNeighborsClassifier    0.028747  0.027998  0.740936
# MLPClassifier_HLs(100)  0.030687  0.030294  1.160660
# RandomForestClassifier  0.047970  0.046908  0.750119
# SVC                     0.070224  0.068205  1.365863

# %%
if not params["data_augmentation"]:
    for model_name, probs_df in probs_dict.items():
        print(f"\n{model_name}")
        plt.figure(figsize=(12, 6))

        tasks = sorted(probs_df['Task'].unique())
        x_positions = np.arange(len(tasks))
        width = 0.35

        # Plot bars and scatter points for each class
        for i, class_name in enumerate(params["classes"]):
            means = probs_df.groupby('Task')[class_name].mean()
            bars = plt.bar(x_positions + (i-0.5)*width, [means[task] for task in tasks], width,
                        label=class_name, alpha=0.7)

            # Add scatter points
            for j, task in enumerate(tasks):
                task_data = probs_df[probs_df['Task'] == task][class_name]
                x_jitter = np.random.normal(0, 0.04, size=len(task_data))
                plt.scatter(np.repeat(x_positions[j] + (i-0.5)*width, len(task_data)) + x_jitter,
                        task_data, color='black', alpha=0.1, s=30)

        plt.xlabel('Task')
        plt.ylabel('Probability')
        plt.title(f'Class Probabilities by Task - {model_name}')
        plt.xticks(x_positions, tasks, rotation=45)
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.ylim(-0.05, 1.05)
        plt.tight_layout()
        plt.show()

        # Summary
        agg_cols = {}
        for cls_name in params["classes"]:
            agg_cols[cls_name] = ["mean", "count", "std"]
        probs_stats = probs_df.groupby("Task").agg(agg_cols)
        display(probs_stats)
# Out:
# RandomForestClassifier
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
#            NoStress                    Stress
#                mean count       std      mean count       std
# Task
# Breathing  0.762118    64  0.110556  0.237882    64  0.110556
# Counting1  0.331771    64  0.155513  0.668229    64  0.155513
# Counting2  0.326632    64  0.151795  0.673368    64  0.151795
# Counting3  0.370970    63  0.179487  0.629030    63  0.179487
# Math       0.346562    64  0.167016  0.653438    64  0.167016
# Reading    0.362639    64  0.160527  0.637361    64  0.160527
# Relax      0.695914    62  0.117677  0.304086    62  0.117677
# Speaking   0.338299    64  0.161222  0.661701    64  0.161222
# Stroop     0.337326    64  0.146121  0.662674    64  0.146121
# Video1     0.744868    63  0.117487  0.255132    63  0.117487
# Video2     0.659824    63  0.121012  0.340176    63  0.121012
# KNeighborsClassifier
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
#            NoStress                    Stress
#                mean count       std      mean count       std
# Task
# Breathing  0.771139    64  0.291666  0.228861    64  0.291666
# Counting1  0.333466    64  0.356641  0.666534    64  0.356641
# Counting2  0.307747    64  0.366955  0.692253    64  0.366955
# Counting3  0.325951    63  0.365669  0.674049    63  0.365669
# Math       0.322723    64  0.362816  0.677277    64  0.362816
# Reading    0.285402    64  0.348565  0.714598    64  0.348565
# Relax      0.628290    62  0.373701  0.371710    62  0.373701
# Speaking   0.297164    64  0.349661  0.702836    64  0.349661
# Stroop     0.286939    64  0.348440  0.713061    64  0.348440
# Video1     0.759919    63  0.305482  0.240081    63  0.305482
# Video2     0.657741    63  0.350058  0.342259    63  0.350058
# SVC
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
#            NoStress                    Stress
#                mean count       std      mean count       std
# Task
# Breathing  0.594759    64  0.144390  0.405241    64  0.144390
# Counting1  0.423843    64  0.127695  0.576157    64  0.127695
# Counting2  0.402258    64  0.122699  0.597742    64  0.122699
# Counting3  0.440396    63  0.153191  0.559604    63  0.153191
# Math       0.411326    64  0.140318  0.588674    64  0.140318
# Reading    0.450500    64  0.138152  0.549500    64  0.138152
# Relax      0.544248    62  0.145784  0.455752    62  0.145784
# Speaking   0.404383    64  0.114377  0.595617    64  0.114377
# Stroop     0.423856    64  0.122754  0.576144    64  0.122754
# Video1     0.544346    63  0.153629  0.455654    63  0.153629
# Video2     0.528898    63  0.118346  0.471102    63  0.118346
# MLPClassifier_HLs(100)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
#            NoStress                    Stress
#                mean count       std      mean count       std
# Task
# Breathing  0.873543    64  0.267882  0.126457    64  0.267882
# Counting1  0.243444    64  0.345249  0.756556    64  0.345249
# Counting2  0.310201    64  0.406971  0.689799    64  0.406971
# Counting3  0.269433    63  0.374324  0.730567    63  0.374324
# Math       0.323627    64  0.392789  0.676373    64  0.392789
# Reading    0.268060    64  0.398636  0.731940    64  0.398636
# Relax      0.797827    62  0.319891  0.202173    62  0.319891
# Speaking   0.324717    64  0.401162  0.675283    64  0.401162
# Stroop     0.300627    64  0.384299  0.699373    64  0.384299
# Video1     0.796720    63  0.320317  0.203280    63  0.320317
# Video2     0.651363    63  0.403892  0.348637    63  0.403892

# %% [markdown]
# ### Ternary classification

# %%
params['classification'] = 'ternary'
params['classes'] = TER_LABELS
y = labels['affect3-class']
show_label_stats(params['classes'], y)

if params["data_augmentation"]:
    ada = ADASYN(random_state=params["state_int"], sampling_strategy={0:400, 1:400, 2:400})
    x_in, y_in = ada.fit_resample(x, y)
    print("Resampled dataset")
    show_label_stats(params['classes'], y_in)
else:
    x_in = x.copy()
    y_in = y.copy()
# Out:
#        labels  counts  percentage
# 0     Relaxed     285   40.772532
# 1      Stress     271   38.769671
# 2  RealStress     143   20.457797

# %%
# 10 random splits holdout
if validations["holdout"]:
    res, conf, models, probs_dict = make_nclassif_random_splits(
        x_in,
        y_in,
        n_splits=params["n_splits"],
        feature_selector=params["feature_selector"],
        list_classifiers=list_classif,
        random_seed=params["state_int"],
        test_size=params["test_size"],
        verbose=params["verbose"],
        useStratification=True,
    )
    output(res, conf, params)
    if params["save_models"]:
        save_models(models, params)

    print(f"Standard Deviations {params['n_splits']} holdouts:")
    display(res.groupby(["classifier"]).std()[["f1-score", "accuracy", "time"]])
# Out:
# Split  1/10
# /Users/sergio-de/Documents/Research/PhDCourse/UXFrustrationRecognition/lib/python3.13/site-packages/sklearn/linear_model/_bayes.py:291: RuntimeWarning: overflow encountered in dot
#   XT_y = np.dot(X.T, y)
# /Users/sergio-de/Documents/Research/PhDCourse/UXFrustrationRecognition/lib/python3.13/site-packages/sklearn/linear_model/_bayes.py:291: RuntimeWarning: overflow encountered in dot
#   XT_y = np.dot(X.T, y)
# /Users/sergio-de/Documents/Research/PhDCourse/UXFrustrationRecognition/lib/python3.13/site-packages/sklearn/linear_model/_bayes.py:291: RuntimeWarning: overflow encountered in dot
#   XT_y = np.dot(X.T, y)
# /Users/sergio-de/Documents/Research/PhDCourse/UXFrustrationRecognition/lib/python3.13/site-packages/sklearn/linear_model/_bayes.py:291: RuntimeWarning: overflow encountered in dot
#   XT_y = np.dot(X.T, y)
# Split  2/10
# Split  3/10
# Split  4/10
# Split  5/10
# Split  6/10
# Split  7/10
# Split  8/10
# Split  9/10
# Split 10/10
#                         f1-score  accuracy      time
# classifier
# KNeighborsClassifier    0.547204  0.513598  8.905237
# MLPClassifier_HLs(100)  0.528696  0.489748  8.935123
# RandomForestClassifier  0.544970  0.507260  9.599694
# SVC                     0.511331  0.474247  8.874199
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Standard Deviations 10 holdouts:
#                         f1-score  accuracy      time
# classifier
# KNeighborsClassifier    0.028348  0.030138  1.148668
# MLPClassifier_HLs(100)  0.024644  0.024156  1.460897
# RandomForestClassifier  0.033869  0.029992  0.956804
# SVC                     0.031780  0.036773  1.363329

# %%
# 5-fold cross-validation
if validations["kfold"]:
    res, conf, models, probs_dict = make_nclassif_kfold(
        x_in,
        y_in,
        feature_selector=params["feature_selector"],
        list_classifiers=list_classif,
        random_seed=params["state_int"],
        verbose=params["verbose"],
        stratified=True,
    )
    output(res, conf, params)
    if params["save_models"]:
        save_models(models, params)

    print("Standard Deviations 5-folds cross-validation:")
    display(res.groupby(["classifier"]).std()[["f1-score", "accuracy", "time"]])
# Out:
# Fold 1/5
# Fold 2/5
# Fold 3/5
# Fold 4/5
# Fold 5/5
#                         f1-score  accuracy      time
# classifier
# KNeighborsClassifier    0.550796  0.518326  7.905640
# MLPClassifier_HLs(100)  0.529439  0.488802  8.568439
# RandomForestClassifier  0.555800  0.515590  8.671133
# SVC                     0.503109  0.462810  7.642569
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Standard Deviations 5-folds cross-validation:
#                         f1-score  accuracy      time
# classifier
# KNeighborsClassifier    0.026993  0.020680  1.504651
# MLPClassifier_HLs(100)  0.023007  0.025931  1.936923
# RandomForestClassifier  0.042710  0.036514  1.147245
# SVC                     0.024474  0.021146  1.464743

# %% [markdown]
# ### Quaternary Classification

# %%
params["classification"] = "quaternary"
params["classes"] = QAD_LABELS
y = labels["affect4-class"]
show_label_stats(params["classes"], y)

if params["data_augmentation"]:
    ada = ADASYN(random_state=params["state_int"], sampling_strategy={0:350, 1:350, 2:350, 3:350})
    x_in, y_in = ada.fit_resample(x, y)
    print("Resampled dataset")
    show_label_stats(params["classes"], y_in)
else:
    x_in = x.copy()
    y_in = y.copy()
# Out:
#        labels  counts  percentage
# 0     Relaxed     215   30.758226
# 1      Stress     195   27.896996
# 2  RealStress     167   23.891273
# 3      Amused     122   17.453505

# %%
# 10 random splits holdout
if validations["holdout"]:
    res, conf, models, probs_dict = make_nclassif_random_splits(
        x_in,
        y_in,
        n_splits=params["n_splits"],
        feature_selector=params["feature_selector"],
        list_classifiers=list_classif,
        random_seed=params["state_int"],
        test_size=params["test_size"],
        verbose=params["verbose"],
        useStratification=True,
    )
    output(res, conf, params)
    if params["save_models"]:
        save_models(models, params)

    print(f"Standard Deviations {params['n_splits']} holdouts:")
    display(res.groupby(["classifier"]).std()[["f1-score", "accuracy", "time"]])
# Out:
# Split  1/10
# Split  2/10
# Split  3/10
# Split  4/10
# Split  5/10
# Split  6/10
# Split  7/10
# Split  8/10
# Split  9/10
# Split 10/10
#                         f1-score  accuracy      time
# classifier
# KNeighborsClassifier    0.451518  0.447752  8.370392
# MLPClassifier_HLs(100)  0.421795  0.423508  8.930140
# RandomForestClassifier  0.460155  0.456668  8.919185
# SVC                     0.414080  0.420994  8.060623
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Standard Deviations 10 holdouts:
#                         f1-score  accuracy      time
# classifier
# KNeighborsClassifier    0.031171  0.034623  0.805904
# MLPClassifier_HLs(100)  0.023121  0.022789  1.400974
# RandomForestClassifier  0.035047  0.041529  1.192265
# SVC                     0.055702  0.053643  1.433266

# %%
# 5-fold cross-validation
if validations["kfold"]:
    res, conf, models, probs_dict = make_nclassif_kfold(
        x_in,
        y_in,
        feature_selector=params["feature_selector"],
        list_classifiers=list_classif,
        random_seed=params["state_int"],
        verbose=params["verbose"],
        stratified=True,
    )
    output(res, conf, params)
    if params["save_models"]:
        save_models(models, params)

    print("Standard Deviations 5-folds cross-validation:")
    display(res.groupby(["classifier"]).std()[["f1-score", "accuracy", "time"]])
# Out:
# Fold 1/5
# Fold 2/5
# Fold 3/5
# Fold 4/5
# /Users/sergio-de/Documents/Research/PhDCourse/UXFrustrationRecognition/lib/python3.13/site-packages/sklearn/linear_model/_bayes.py:291: RuntimeWarning: invalid value encountered in dot
#   XT_y = np.dot(X.T, y)
# Fold 5/5
#                         f1-score  accuracy      time
# classifier
# KNeighborsClassifier    0.413052  0.410051  9.070503
# MLPClassifier_HLs(100)  0.408488  0.403923  9.852152
# RandomForestClassifier  0.451342  0.446124  9.370846
# SVC                     0.399341  0.409472  9.021022
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Standard Deviations 5-folds cross-validation:
#                         f1-score  accuracy      time
# classifier
# KNeighborsClassifier    0.041377  0.037825  1.065312
# MLPClassifier_HLs(100)  0.049164  0.059237  1.625837
# RandomForestClassifier  0.030470  0.033404  1.493053
# SVC                     0.038881  0.043345  1.490023
